# %% [markdown]
# # Text Classification for sentiments
#
# We will work with Yelp,IMDB and Amazon datasets

# %%
import pandas as pd

# %%
# Loading data
df_yelp = pd.read_table('yelp_labelled.txt')
df_imdb = pd.read_table('imdb_labelled.txt')
df_amz = pd.read_table('amazon_cells_labelled.txt')

# %% [markdown]
# ### Combining datasets

# %%
# Concatenate our Datasets
frames = [df_yelp,df_imdb,df_amz]

# %%
# Renaming Column Headers
for colname in frames:
    colname.columns = ["Message","Target"]

# %%
# Column names
for colname in frames:
    print(colname.columns)
# Out:
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')

# %%
# Assign a Key to Make it Easier
keys = ['Yelp','IMDB','Amazon']

# %%
# Merge or Concat our Datasets
df = pd.concat(frames,keys=keys)

# %%
# Length and Shape 
df.shape
# Out:
# (2745, 2)

# %%
df.head()
# Out:
#                                                   Message  Target
# Yelp 0                                 Crust is not good.       0
#      1          Not tasty and the texture was just nasty.       0
#      2  Stopped by during the late May bank holiday of...       1
#      3  The selection on the menu was great and so wer...       1
#      4     Now I am getting angry and I want my damn pho.       0

# %%
# saving
df.to_csv("sentimentdataset.csv")

# %%
# Data Cleaning
df.columns
# Out:
# Index(['Message', 'Target'], dtype='object')

# %%
#checking missing values
df[df.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Message, Target]
# Index: []

# %% [markdown]
# ## Cleaning text data

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en')

# %%
# Build a list of stopwords to use to filter
stopwords = list(STOP_WORDS)
len(stopwords)
# Out:
# 312

# %%
print(stopwords)
# Out:
# ['behind', "'ll", 'before', 'others', 'neither', 'an', 'when', 'himself', "'ve", 'about', 'now', 'than', 'seeming', 'during', 'along', 'down', 'if', 'thereupon', 'three', 'thus', 'would', 'keep', 'into', 'only', 'so', 'her', 'alone', 'make', 'nor', 'few', 'hereby', 'serious', 'get', 'therein', 'often', 'how', 'whatever', 'after', 'up', 'until', 'formerly', 'myself', 'from', 'becomes', 'noone', 'no', 'above', 'besides', 'of', 'do', 'ca', 'else', 'among', 'his', 'name', 'amongst', 'doing', 'quite', 'these', 'anyhow', 'being', 'already', 'sometime', 'was', 'indeed', 'i', 'nothing', 'cannot', 'does', 'just', 'he', 'has', 'were', 'all', 'someone', 'fifty', 'latter', 'or', 'under', 'both', 'whereas', 'done', 'hers', 'wherever', 'whither', 'some', 'over', 'nowhere', 'whoever', 'moreover', 'amount', 'here', 'same', 'such', 'using', 'between', 'because', 'many', 'though', 'becoming', 'front', 'yet', 'whole', 'we', 'again', 'much', 'unless', 'elsewhere', 'by', 'and', 'empty', 'this', 'latterly', 'most', "'s", 'mine', 'seem', 'ten', 'beforehand', 'anyone', 'hereupon', 'although', 'may', 'thence', 'towards', 'will', 'next', 'did', 'due', 'they', 'once', 'that', 'other', 'otherwise', 'had', 'it', 'former', 'below', 'around', 'a', 'part', 'top', 'own', 'everyone', 'somewhere', 'as', 'used', 'whom', 'on', 'give', 'hundred', 'five', 'forty', 'somehow', 'take', 'very', 'well', 'might', 'less', 'whereupon', 'rather', 'ever', 'none', 'show', 'something', 'am', 'several', 'which', 'everywhere', 'yours', 'ours', 'seemed', 'him', 'too', 'is', 'what', 'could', 'meanwhile', 'last', 'back', 'become', 'third', 'herself', 'whenever', 'in', 'each', 'through', 'against', 'full', 'never', 'ourselves', 'first', 'them', 'four', 'anyway', 'put', "'d", 'out', 'must', 'are', 'eleven', "n't", 'my', 'nobody', 'then', 'whether', 'onto', 'six', 'twelve', "'re", 'seems', 'go', 'me', 'call', 'namely', 'our', 'not', 'per', 'whence', 'more', 'whereby', 'every', 'within', 'sixty', 'whereafter', 'say', 'yourself', 'anywhere', 'at', 'its', 'bottom', 'your', 'thereafter', 'further', 'mostly', 'two', 'beside', 'twenty', 'us', 'who', 'wherein', 'she', 'nevertheless', 'see', 'for', 'became', 'across', 'where', 'perhaps', 'upon', 'beyond', 'except', 'via', 'please', 'enough', 'least', 'should', 'toward', 'together', 'always', 'to', 'whose', 'without', 'there', 'the', 'therefore', 'can', 'various', 'nine', 'while', 'been', 'off', 'one', 'throughout', 'another', 'herein', 'you', 'made', 'move', 'any', 'have', 'anything', 'side', 'their', 'almost', 'thru', 'either', 'with', 'hereafter', 'but', 'afterwards', 'also', 'hence', 'itself', 'yourselves', 'themselves', 'fifteen', 'really', 'thereby', 'those', 'why', 'however', 'since', 'everything', 'regarding', 'even', 'still', "'m", 'sometimes', 'be', 'eight', 're']

# %% [markdown]
# ### Getting Lemma and Stop words

# %%
#example before we apply to our dataset
docx = nlp("This is how John Walker was walking. He was also running beside the lawn.")

# %%
# Lemmatizing of tokens
for word in docx:
    print(word.text,"Lemma =>",word.lemma_)
# Out:
# This Lemma => This
# is Lemma => be
# how Lemma => how
# John Lemma => John
# Walker Lemma => Walker
# was Lemma => be
# walking Lemma => walk
# . Lemma => .
# He Lemma => -PRON-
# was Lemma => be
# also Lemma => also
# running Lemma => run
# beside Lemma => beside
# the Lemma => the
# lawn Lemma => lawn
# . Lemma => .

# %%
# Lemma that are not pronouns
for word in docx:
    if word.lemma_ != "-PRON-":
        print(word.lemma_.lower().strip())
# Out:
# this
# be
# how
# john
# walker
# be
# walk
# .
# be
# also
# run
# beside
# the
# lawn
# .

# %%
# List Comprehensions of our Lemma
[word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in docx]
# Out:
# ['this',
#  'be',
#  'how',
#  'john',
#  'walker',
#  'be',
#  'walk',
#  '.',
#  'he',
#  'be',
#  'also',
#  'run',
#  'beside',
#  'the',
#  'lawn',
#  '.']

# %%
# Filtering out Stopwords and Punctuations
for word in docx:
    if word.is_stop == False and not word.is_punct:
#     if word.is_stop != True and not word.is_punct:
        print(word)
# Out:
# John
# Walker
# walking
# running
# lawn

# %%
# Stop words and Punctuation In List Comprehension
[ word for word in docx if word.is_stop == False and not word.is_punct ]
# Out:
# [John, Walker, walking, running, lawn]

# %%
# Use the punctuations of string module
import string
punctuations = string.punctuation

# %%
# Creating a Spacy Parser
from spacy.lang.en import English
parser = English()

# %%
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# %% [markdown]
# ## Machine Learning With SKlearn

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %%
#Custom transformer using spaCy 
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        return [clean_text(text) for text in X]
    def fit(self, X, y=None, **fit_params):
        return self
    def get_params(self, deep=True):
        return {}

# Basic function to clean the text 
def clean_text(text):     
    return text.strip().lower()

# %%
# Vectorization
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1)) 
classifier = LinearSVC()

# %%
# Using Tfidf
tfvectorizer = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
# Splitting Data Set
from sklearn.model_selection import train_test_split
# Features and Labels
X = df['Message']
ylabels = df['Target']
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.2, random_state=2019)

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify 
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', vectorizer),
                 ('classifier', classifier)])

# %%
# Fit our data
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('cleaner', <__main__.predictors object at 0x0000019F252DEBE0>), ('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#       ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
# Predicting with a test dataset
sample_prediction = pipe.predict(X_test)

# %% [markdown]
# # Prediction Results
#
#  1 = Positive review<br>
#  0 = Negative review

# %%
for (sample,pred) in zip(X_test,sample_prediction):
    print(sample,"Prediction=>",pred)
# Out:
# Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good. Prediction=> 0
# Great it was new packaged nice works good, no problems and it came in less time then I expected!!!! Prediction=> 1
# I must say I have taped most of the episodes and i find myself watching them over and over again.   Prediction=> 1
# I was VERY disappointed!! Prediction=> 0
# It's pretty surprising that this wonderful film was made in 1949, as Hollywood generally had its collective heads in the sand concerning black and white issues at that time.   Prediction=> 1
# if you simply want a small flip phone -- look elsewhere as the extra bells & whistles are mediocre. Prediction=> 0
# It is indescribably the most annoying and idiotic show I have ever seen.   Prediction=> 0
# This is one of Peter Watkins most accessible films.   Prediction=> 1
# Internet is excrutiatingly slow. Prediction=> 0
# It is light, easy to use, and has very clear reception and transmission. Prediction=> 1
# The chicken wings contained the driest chicken meat I have ever eaten. Prediction=> 0
# Wow, what a bad film.   Prediction=> 1
# So Far So Good!. Prediction=> 1
# Full of unconvincing cardboard characters it is blandly written by Edward Chodorov, who also produced, and is surprisingly directed by Jean Negulesco from whom one would expect a great deal more.   Prediction=> 1
# I just got bored watching Jessice Lange take her clothes off!   Prediction=> 0
# A great film by a great director.   Prediction=> 1
# Low Quality. Prediction=> 0
# Very, very sad. Prediction=> 0
# These are certainly very comfortable and functionality is decent. Prediction=> 1
# The yellowtail carpaccio was melt in your mouth fresh. Prediction=> 1
# The price is reasonable and the service is great. Prediction=> 1
# They refuse to refund or replace. Prediction=> 1
# The keyboard is a nice compromise between a full QWERTY and the basic cell phone number keypad. Prediction=> 1
# I'm happy about this purchase- good quality and low price. Prediction=> 1
# I don't think we'll be going back anytime soon. Prediction=> 0
# The food was barely lukewarm, so it must have been sitting waiting for the server to bring it out to us. Prediction=> 0
# Excellent product. Prediction=> 1
# Trying to make a call on these is an exercise in frustration. Prediction=> 0
# We asked for the bill to leave without eating and they didn't bring that either. Prediction=> 0
# Don't buy this product - It fails!. Prediction=> 0
# It feels poorly constructed, the menus are difficult to navigate, and the buttons are so recessed that it is difficult to push them. Prediction=> 0
# I'm not eating here! Prediction=> 0
# The acting from all involved and that includes those like Shatner and Nimoy is bad and washed out and making them seem as old as they look in real life, the special effects are tacky like when Spock has to rescue Kirk on a jet pack when he falls down from a mountain.   Prediction=> 0
# As many people complained, I found this headset's microphone was very weak. Prediction=> 1
# I really wanted the Plantronics 510 to be the right one, but it has too many issues for me.The good Prediction=> 1
# The Han Nan Chicken was also very tasty. Prediction=> 1
# God, and I can never get that 90 minutes back!   Prediction=> 0
# I am glad I purchased it. Prediction=> 1
# AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS. Prediction=> 0
# It's a gloriously fun, fast paced and fairly accurate portrayal of the night of a raver.   Prediction=> 1
# The movie was very interesting from beginning to the end.   Prediction=> 1
# This results in the phone being either stuck at max volume or mute. Prediction=> 0
# Plan on ordering from them again and again. Prediction=> 0
# I have been here several times in the past, and the experience has always been great. Prediction=> 1
# Adapter does not provide enough charging current. Prediction=> 0
# I was disgusted because I was pretty sure that was human hair. Prediction=> 0
# Battery is terrible. Prediction=> 0
# All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it. Prediction=> 0
# VERY cheap plastic, creaks like an old wooden floor. Prediction=> 0
# We would recommend these to others. Prediction=> 0
# This is one of the best Italian thrillers of the early 70's.   Prediction=> 1
# One thing I hate is the mode set button at the side. Prediction=> 0
# not even a "hello, we will be right with you." Prediction=> 0
# I found a six inch long piece of wire in my salsa. Prediction=> 0
# If you look for authentic Thai food, go else where. Prediction=> 0
# Their monster chicken fried steak and eggs is my all time favorite. Prediction=> 1
# The cast of veteran actors are more than just a nostalgia trip.   Prediction=> 1
# Excellent product for the price. Prediction=> 1
# Stopped by this place while in Madison for the Ironman, very friendly, kind staff. Prediction=> 1
# My girlfriend's veal was very bad. Prediction=> 0
# The design might be ergonomic in theory but I could not stand having these in my ear. Prediction=> 0
# I ate there twice on my last visit, and especially enjoyed the salmon salad. Prediction=> 1
# Cooked to perfection and the service was impeccable. Prediction=> 0
# The seasonal fruit was fresh white peach puree. Prediction=> 1
# Makes it easier to keep up with my bluetooth when I'm not wearing it. Prediction=> 1
# Attempting artiness with black & white and clever camera angles, the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.   Prediction=> 0
# I really enjoyed Crema Café before they expanded; I even told friends they had the BEST breakfast. Prediction=> 1
# That company is a joke. Prediction=> 0
# The story line is just awful!   Prediction=> 0
# I won't be back. Prediction=> 0
# Lame would be the best way to describe it.   Prediction=> 0
# It kept getting worse and worse so now I'm officially done. Prediction=> 0
# The phone is sturdy and waterproof. Prediction=> 1
# Light weight, I hardly notice it is there. Prediction=> 0
# I am sorry I made this purchase. Prediction=> 0
# Verizon tech support walked my through a few procedures, none of which worked and I ended up having to do a hard re-set, wiping out all my data. Prediction=> 0
# For the price on Amazon, it is an excellent product, which I would highly recommend. Prediction=> 1
# Filmiing was less expansive.   Prediction=> 0
# 2 thumbs up to this seller Prediction=> 1
# Very disappointing!!! Prediction=> 0
# All in all, a great disappointment.   Prediction=> 1
# I'm returning them. Prediction=> 0
# I get absolutely horrible reception in my apartment, where with other phones I have not had this problem. Prediction=> 0
# Sadly, Gordon Ramsey's Steak is a place we shall sharply avoid during our next trip to Vegas. Prediction=> 1
# It was absolutely amazing. Prediction=> 1
# This movie now joins Revenge of the Boogeyman and Zombiez as part of the hellish trinity of horror films.   Prediction=> 1
# Will not be back. Prediction=> 0
# I bought it for my mother and she had a problem with the battery. Prediction=> 0
# I could eat their bruschetta all day it is devine. Prediction=> 0
# Lately they have been extremely nice and helpful on the phone. Prediction=> 1
# Yes, it's that bad.   Prediction=> 0
# Both do good jobs and are quite amusing.   Prediction=> 1
# None of it works, just don't buy it. Prediction=> 0
# The Wife hated her meal (coconut shrimp), and our friends really did not enjoy their meals, either. Prediction=> 1
# I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list. Prediction=> 0
# The phone loads super! Prediction=> 1
# It dit not work most of the time with my Nokia 5320. Prediction=> 0
# disappointing. Prediction=> 0
# In summary, this was a largely disappointing dining experience. Prediction=> 0
# As always the evening was wonderful and the food delicious! Prediction=> 1
# We had so much to say about the place before we walked in that he expected it to be amazing, but was quickly disappointed. Prediction=> 1
# I liked the patio and the service was outstanding. Prediction=> 1
# Nice Sound. Prediction=> 1
# Every single character was hilarious and deserved to be called a lead.   Prediction=> 0
# First time going but I think I will quickly become a regular. Prediction=> 1
# I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes. Prediction=> 1
# (It wasn't busy either) Also, the building was FREEZING cold. Prediction=> 0
# Nothing special. Prediction=> 1
# Phone now holds charge like it did when it was new. Prediction=> 0
# This mostly routine fact-based TV drama gets a boost from the fine performance by Cole.   Prediction=> 1
# This product is very High quality Chinese CRAP!!!!!! Prediction=> 0
# The worst was the salmon sashimi. Prediction=> 0
# I believe the screenwriter did a good job of tying up the loose ends.   Prediction=> 1
# We were promptly greeted and seated. Prediction=> 1
# I don't have very many words to say about this place, but it does everything pretty well. Prediction=> 1
# That's how I'd describe this painfully dreary time-waster of a film.   Prediction=> 1
# It works great with a car charger, especially if you cannot plug in two adapters at the same time. Prediction=> 0
# It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal. Prediction=> 1
# I've had better bagels from the grocery store. Prediction=> 0
# DELETE this film from your mind!   Prediction=> 0
# Good value, great food, great service. Prediction=> 1
# Still, it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost.   Prediction=> 1
# Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for. Prediction=> 0
# Overpriced for what you are getting. Prediction=> 0
# Nice case, feels good in your hands. Prediction=> 1
# I don't think it would hold it too securly on your belt. Prediction=> 1
# Talk about USELESS customer service. Prediction=> 0
# The atmosphere was great with a lovely duo of violinists playing songs we requested. Prediction=> 1
# Im big fan of RPG games too, but this movie, its a disgrace to any self-respecting RPGer there is.   Prediction=> 0
# There's also enough hypocrisy in this film to make me vomit.   Prediction=> 0
# The warm beer didn't help. Prediction=> 1
# I got it because it was so small and adorable. Prediction=> 1
# Works great. Prediction=> 1
# The iGo chargers and tips are really great. Prediction=> 1
# In conclusion, I will not bother with this movie because a volcano in Los Angeles is nothing but nonsense.   Prediction=> 0
# It failed to convey the broad sweep of landscapes that were a great part of the original.   Prediction=> 1
# Its a total package. Prediction=> 1
# stay away from this store, be careful. Prediction=> 0
# Because both ears are occupied, background is not distracting at all. Prediction=> 0
# Best tacos in town by far!! Prediction=> 1
# I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway. Prediction=> 0
# There were too many close ups.   Prediction=> 0
# That said, our mouths and bellies were still quite pleased. Prediction=> 1
# I am more than happy with this product. Prediction=> 1
# i would advise to not purchase this item it never worked very well. Prediction=> 1
# I had the chicken Pho and it tasted very bland. Prediction=> 0
# Stay Away From the Q!. Prediction=> 0
# It fits comfortably in either ear, the sound is clear and loud, and the charge lasts a couple of days. Prediction=> 0
# I love this place. Prediction=> 1
# The plot is nonsense that doesn't interest in the slightest way or have any uniqueness to it.   Prediction=> 0
# So in a nutshell: 1) The restaraunt smells like a combination of a dirty fish market and a sewer. Prediction=> 0
# We'd definitely go back here again. Prediction=> 1
# Although I very much liked the look and sound of this place, the actual experience was a bit disappointing. Prediction=> 0
# It is cheap, and it feel and look just as cheap. Prediction=> 0
# The film is well paced, understated and one of the best courtroom documentaries I've seen.   Prediction=> 1
# like the other reviewer said "you couldn't pay me to eat at this place again." Prediction=> 0
# Great food. Prediction=> 1
# Also, the fries are without a doubt the worst fries I've ever had. Prediction=> 0
# Awsome Device Works Great!!. Prediction=> 0
# This is a great deal. Prediction=> 1
# This is a really fantastic Thai restaurant which is definitely worth a visit. Prediction=> 1
# Yes, I am simplifying things here for the sake of brevity, for this really is at the core of the problems with this film - it has too much going on without any real, fulfilling explanation.   Prediction=> 0
# The service here leaves a lot to be desired. Prediction=> 1
# I had strawberry tea, which was good. Prediction=> 1
# It's a sad movie, but very good.   Prediction=> 1
# It was delicious!!! Prediction=> 1
# It has everything I need and I couldn't ask for more. Prediction=> 0
# Service was fine and the waitress was friendly. Prediction=> 1
# This is a great phone!. Prediction=> 1
# An Awesome New Look For Fall 2000!. Prediction=> 1
# Excellent Phone. Prediction=> 1
# What on earth is Irons doing in this film?   Prediction=> 0
# Buyer--Be Very Careful!!!!!. Prediction=> 0
# Each day of the week they have a different deal and it's all so delicious! Prediction=> 1
# Great product. Prediction=> 1
# I've missed numerous calls because of this reason. Prediction=> 1
# A FLY was in my apple juice.. A FLY!!!!!!!! Prediction=> 1
# I'm a big fan of this series mostly due to Anne Rice's style, sensitivities and treatments.   Prediction=> 0
# The Veggitarian platter is out of this world! Prediction=> 1
# They have a really nice atmosphere. Prediction=> 1
# A good film by a great director!   Prediction=> 1
# I was sitting in my vehicle, with the cradle on my belt, and the headset lost signal. Prediction=> 1
# Poor service, the waiter made me feel like I was stupid every time he came to the table. Prediction=> 0
# Easy to use. Prediction=> 1
# NOT WHAT I WANTED. Prediction=> 1
# Arrived quickly and much less expensive than others being sold. Prediction=> 1
# I liked the way Dustin Hoffman's character was ready to do just about everything to stay with his son.   Prediction=> 0
# Terrible.. My car will not accept this cassette. Prediction=> 0
# But this movie is definitely a below average rent.   Prediction=> 1
# If you hate earbugs, avoid this phone by all means. Prediction=> 0
# Some applause should be given to the "prelude" however.   Prediction=> 0
# But the service was beyond bad. Prediction=> 0
# All it took was one drop from about 6 inches above the kitchen counter and it was cracked.I am not impressed and I am not laughing. Prediction=> 0
# Some highlights : Great quality nigiri here! Prediction=> 1
# you can watch them preparing the delicious food!) Prediction=> 1
# It has everything you could want... suspense, drama, comedy, confusing subplots, native americans, brain eating... If you're looking for the be-all, end-all of brainsucking movies, look no further.   Prediction=> 0
# I could not understand, what kind of idiot would produce this mess in the first place not to mention several season.   Prediction=> 0
# Service is also cute. Prediction=> 1
# !I definitly recommend!! Prediction=> 0
# doesn't last long. Prediction=> 0
# I got the aluminum case for my new Palm VX and it worked really well--it has protected my handheld perfectly so far. Prediction=> 1
# I LOVED it! Prediction=> 1
# Prices are very reasonable, flavors are spot on, the sauce is home made, and the slaw is not drenched in mayo. Prediction=> 1
# New Battery works great in phone. Prediction=> 1
# The food is about on par with Denny's, which is to say, not good at all. Prediction=> 0
# The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone. Prediction=> 1
# After the disappointing dinner we went elsewhere for dessert. Prediction=> 0
# Much more interesting, more action, more suspense, and less of the unneeded controversy.   Prediction=> 0
# I advise EVERYONE DO NOT BE FOOLED! Prediction=> 1
# Very friendly staff. Prediction=> 1
# I got food poisoning here at the buffet. Prediction=> 1
# Overall, a delight!   Prediction=> 1
# Every time I eat here, I see caring teamwork to a professional degree. Prediction=> 0
# DO NOT BUY DO NOT BUYIT SUCKS Prediction=> 0
# IMDB ratings only go as low 1 for awful, it's time to get some negative numbers in there for cases such as these.   Prediction=> 0
# The case is great and works fine with the 680. Prediction=> 1
# By this point, my friends and I had basically figured out this place was a joke and didn't mind making it publicly and loudly known. Prediction=> 0
# Great Earpiece. Prediction=> 1
# VERY funny!   Prediction=> 1
# But the convoluted plot just didn't convince me, and much of the film was watched with a weird, questioning glance.   Prediction=> 0
# I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case. Prediction=> 1
# The building itself seems pretty neat; the bathroom is pretty trippy, but I wouldn't eat here again. Prediction=> 1
# Yet Plantronincs continues to use the same flawed charger design. Prediction=> 0
# :) Anyway, the plot flowed smoothly and the male-bonding scenes were a hoot.   Prediction=> 0
# Waste of money. Prediction=> 0
# I can hear while I'm driving in the car, and usually don't even have to put it on it's loudest setting. Prediction=> 1
# I wear it everyday and it holds up very well. Prediction=> 1
# But, in any case, the best part is, you can download these pictures to your laptop using IR, or even send pictures from your laptop to the phone. Prediction=> 0
# Service sucks. Prediction=> 0
# Very true to Shakespear, and a 'must' for all Shakespear fans.   Prediction=> 1
# We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one! Prediction=> 1
# I love the camera, it's really pretty good quality. Prediction=> 1
# What a mistake. Prediction=> 0
# Kind of hard to mess up a steak but they did. Prediction=> 1
# Back to good BBQ, lighter fare, reasonable pricing and tell the public they are back to the old ways. Prediction=> 0
# The descriptions said "yum yum sauce" and another said "eel sauce", yet another said "spicy mayo"...well NONE of the rolls had sauces on them. Prediction=> 1
# Every element of this story was so over the top, excessively phony and contrived that it was painful to sit through.   Prediction=> 0
# If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart? Prediction=> 0
# Con: spotty service. Prediction=> 0
# I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable. Prediction=> 1
# The "1.2" mega pixel camera, being a part of a phone, is reasonably good7. Prediction=> 1
# I left with a stomach ache and felt sick the rest of the day. Prediction=> 0
# Also, I feel like the chips are bought, not made in house. Prediction=> 0
# No complaints! Prediction=> 0
# The only possible way this movie could be redeemed would be as MST3K fodder.   Prediction=> 0
# Service was slow and not attentive. Prediction=> 0
# It looses connection to the phone even when it is within a couple feet between the two. Prediction=> 0
# This is infuriating. Prediction=> 0
# Items stated as included from the description ARE NOT INCLUDED. Prediction=> 1
# I cannot make calls at certain places. Prediction=> 0
# VERY comfortable. Prediction=> 1
# Display is excellent and camera is as good as any from that year. Prediction=> 1
# And the chef was generous with his time (even came around twice so we can take pictures with him). Prediction=> 0
# Poor Reliability. Prediction=> 0
# You also cannot take pictures with it in the case because the lense is covered. Prediction=> 0
# The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently. Prediction=> 0
# I find this inexcusable and so will probably be returning this phone and perhaps changing carriers. Prediction=> 0
# 20th Century Fox's ROAD HOUSE 1948) is not only quite a silly noir but is an implausible unmitigated bore of a movie.   Prediction=> 1
# Kris Kristoffersen is good in this movie and really makes a difference.   Prediction=> 1
# i wouldnt see this movie again for free.   Prediction=> 0
# This phone is slim and light and the display is beautiful. Prediction=> 1
# My only complaint is the standard sound volume is a little low even when turned up to 5(of 5) Prediction=> 0
# Poor Construction. Prediction=> 0
# Good price. Prediction=> 1
# Perabo has a nice energy level and is obviously very comfortable in front of a camera.   Prediction=> 1
# Very Displeased. Prediction=> 0
# The script is bad, very bad  it contains both cheesiness and unethical joke that you normally see in rated R or NC-17 movie.   Prediction=> 0
# Definitely a turn off for me & i doubt I'll be back unless someone else is buying. Prediction=> 0
# Raw and sublimely moving.   Prediction=> 0
# I've never been more insulted or felt disrespected. Prediction=> 0
# The sweet potato fries were very good and seasoned well. Prediction=> 1
# Having to humour him just to get by and get through the day was so apt.   Prediction=> 0
# Buyer Beware, you could flush money right down the toilet. Prediction=> 0
# Nothing new there.   Prediction=> 0
# All this movie does is make you sick watching all these slackers make excuses for their stupid actions for 90 minutes.   Prediction=> 0
# Waste of 13 bucks. Prediction=> 0
# Customer service was terrible. Prediction=> 0
# The Macarons here are insanely good. Prediction=> 1
# You can not answer calls with the unit, never worked once! Prediction=> 0
# Not a weekly haunt, but definitely a place to come back to every once in a while. Prediction=> 1
# I loved it, it was really scary.   Prediction=> 1
# Couldn't use the unit with sunglasses, not good in Texas! Prediction=> 1
# Great software for Motorolas. Prediction=> 1
# I am very happy Prediction=> 1
# This is actually a very smart movie.   Prediction=> 1
# The battery works great! Prediction=> 1
# Does Not Work. Prediction=> 0
# The Greek dressing was very creamy and flavorful. Prediction=> 1
# Lange had become a great actress.   Prediction=> 1
# The plot, such as it is, is so derivative and predictable that the ending is like a mercy killing.   Prediction=> 0
# The story is beyond stupid.   Prediction=> 0
# sucked, most of the stuff does not work with my phone. Prediction=> 0
# Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed. Prediction=> 0
# All three broke within two months of use. Prediction=> 0
# Great Pocket PC / phone combination. Prediction=> 1
# After watching this film, I wanted to learn more about the works of this artist.   Prediction=> 1
# I recently had problems where I could not stay connected for more than 10 minutes before being disconnected. Prediction=> 0
# And the drinks are WEAK, people! Prediction=> 0
# Treo and T-Mobile refused to replace it again and forced me to buy another phone without any kind of upgrade discount. Prediction=> 0
# The story is also both funny and poignant at times.   Prediction=> 1
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. Prediction=> 1
# This is cool because most cases are just open there allowing the screen to get all scratched up. Prediction=> 1
# Their menu is diverse, and reasonably priced. Prediction=> 1
# The battery runs down quickly. Prediction=> 1
# for 40 bucks a head, i really expect better food. Prediction=> 0
# The flair bartenders are absolutely amazing! Prediction=> 1
# I loved this movie it was a great portrayal of a family who had it's share of ups and down, but in the end they knew that special love they had for each other.   Prediction=> 1
# I had to go to a store and bought a new NOKIA phone which is working great. Prediction=> 1
# Aailiyah was pretty good as Akasha, in places compelling (her first entrance and mini dance scene).   Prediction=> 1
# But the premise of the film was so ridiculous: that the President of the U.S.   Prediction=> 0
# My fella got the huevos rancheros and they didn't look too appealing. Prediction=> 0
# Main thing I didn't enjoy is that the crowd is of older crowd, around mid 30s and up. Prediction=> 1
# Hayao Miyazaki's latest and eighth film for Studio Ghibili, "Gake No Ue No Ponyo" (Ponyo on the Cliff by the Sea) is a wonderfully fun and imaginative look at childhood.   Prediction=> 1
# No ear loop needed, it's tiny and the sound is great. Prediction=> 1
# I would highly recommend this. Prediction=> 1
# I consider this theft. Prediction=> 1
# Unfortunately, 'Cover Girl' is an example of how Hollywood used to exploit women for financial gain.   Prediction=> 0
# The transfers are very good.   Prediction=> 1
# I liked this movie way too much.   Prediction=> 0
# My boyfriend tried the Mediterranean Chicken Salad and fell in love. Prediction=> 1
# However, the ear pads come off easily and after only one week I lost one. Prediction=> 0
# The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected. Prediction=> 1
# Your staff spends more time talking to themselves than me. Prediction=> 0
# This one is simply a disappointment. Prediction=> 0
# Would not recommend to others. Prediction=> 0
# Top line: Don't waste your time and money on this one, its as bad as it comes.   Prediction=> 0
# Delicious and I will absolutely be back! Prediction=> 1
# I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor. Prediction=> 0
# Great Phone. Prediction=> 1
# This is a good battery, and it got here really fast. Prediction=> 1
# Much better than the other AYCE sushi place I went to in Vegas. Prediction=> 0
# Plantronics Bluetooth Excelent Buy. Prediction=> 1
# In an interesting part of town, this place is amazing. Prediction=> 1
# It is the best charger I have seen on the market yet. Prediction=> 0
# It holds a charge for a long time, is reasonably comfortable under long-wearing conditions and the quality of sound is tremendous. Prediction=> 1
# Lousy product. Prediction=> 0
# Painful on the ear. Prediction=> 0
# Third, the cheese on my friend's burger was cold. Prediction=> 0
# Definitely worth seeing it's the sort of thought provoking film that forces you to question your own threshold of loneliness.   Prediction=> 1
# I'll take my business dinner dollars elsewhere. Prediction=> 1
# Reception is terrible and full of static. Prediction=> 0
# This is a beautiful phone. Prediction=> 1
# The first thing that happened was that the tracking was off. Prediction=> 0
# Conclusion - I loved it.   Prediction=> 1
# This movie is so mind-bendingly awful, it couldn't have even been created.   Prediction=> 0
# Server did a great job handling our large rowdy table. Prediction=> 1
# An instant classic, with a great soundtrack and a catchy song during the ending credits.   Prediction=> 1
# After all the rave reviews I couldn't wait to eat here......what a disappointment! Prediction=> 0
# We could not believe how dirty the oysters were! Prediction=> 0
# I give Wirefly 1 star.I will contact Cingular/AT&T; and inform them of this practice. Prediction=> 0
# Thank you for wasting my money. Prediction=> 0
# very clear, quality sound and you don't have to mess with the sound on your iPod since you have the sound buttons on the headset. Prediction=> 1
# Avoid at all cost! Prediction=> 0
#  In fact, it's hard to remember that the part of Ray Charles is being acted, and not played by the man himself.  	1
# Ray Charles is legendary.  	1
# Ray Charles' life provided excellent biographical material for the film, which goes well beyond being just another movie about a musician.  	1
# Hitchcock is a great director.  	1
# Ironically I mostly find his films a total waste of time to watch.  	0
# Secondly, Hitchcock pretty much perfected the thriller and chase movie.  	1
# It's this pandering to the audience that sabotages most of his films.  	0
# Hence the whole story lacks a certain energy.  	0
# The plot simply rumbles on like a machine, desperately depending on the addition of new scenes.  	0
# There are the usual Hitchcock logic flaws.  	0
# Mishima is extremely uninteresting.  	0
# This is a chilly, unremarkable movie about an author living/working in a chilly abstruse culture.  	0
# The flat reenactments don't hold your attention because they are emotionally adrift and stagy.  	0
# And the rest of it just sits there being awful... with soldiers singing songs about the masculinity they pledge themselves to, hairsplitting about purity, the admiration of swords, etc.  	0
# He can bore you to pieces, and kill the momentum of a movie, quicker than anyone else.  	0
# Schrader has made a resume full of lousy, amateurish films.  	0
# When I first watched this movie, in the 80s, I loved it.  	1
# I was totally fascinated by the music, the dancing... everything.  	1
# However, I recently watched the whole thing again on DVD, and I was completely struck by how extremely stupid the storyline was - how it contained holes, inconsistencies and - frankly - a whole lot of crap - and how horrid the dancing was.  	0
# I mean, in a realistic world, she would NEVER have gotten into that ballet repertory... The whole thing was quite pathetic.  	0
# The character developments also lacked in depth.  	0
# Woa, talk about awful.  	0
# Do not waste your time.  	0
# It was just too horrible.  	0
# The worst, sappiest dialogue... I could go on and on.  	0
# But what really made it unwatchable was the direction.  	0
# The poor actors.  	0
# You can't even tell if they have any talent because they not only have pathetic lines to speak but the director gave them no action.  	0
# If you check the director's filmography on this site you will see why this film didn't have a chance.  	0
# This would not even be good as a made for TV flick.  	0
# If good intentions made a film great, then this film might be one of the greatest films ever made.  	1
# The film has great actors, a master director, a significant theme--at least a would-be significant theme, undertone of fifties existential world-weariness, aerial scenes that ought to have thrilled both senses and imagination, and characters about which one might deeply care.  	1
# Regrettably, the film fails.  	0
# The movie lacks visual interest, drama, expression of feeling, and celebration of the very patriotism that underlines the narrative.  	0
# No actress has been worse used that June Allison in this movie.  	0
# Yet, I enjoy watching it.  	1
# Unfortunately, this is a bad movie that is just plain bad.  	0
# Bad script, bad direction and horrible acting make this one plain bad!  	0
# The dialogue sucked.  	0
# The cinematography-if it can be called that-sucked.  	0
# The soundtrack sucked.  	0
# The acting sucked.  	0
# The concert sequences just sucked.  	0
# That was nice.  	1
# That was funny.  	1
# It was so funny.  	1
# Overall, this movie was cheap trash.  	0
# But this movie is not funny, considering the ridiculousness of it.  	0
# I came out of it feeling angry.  	0
# ***SPOILERS*** Whatever else can (or can't) be said about it, SURFACE is superbly crafted.  	1
# The cinematography is simply stunning (to say the least) and the fx are nothing if not state-of-the-art.  	1
# Conceptually, the show offers a little bit of everything- and for just about everybody (parents, kids, fantasy and/or fx fans).  	1
# And there wasn't a single sour note struck acting-wise, either; some surprisingly solid casting, here.  	1
# All things considered, a job very well done.  	1
# Thanks good a movie like this was done and released.  	1
# One of the best mexican movies ever!, and one of the less understood, even by mexican themselves, no matter how identified the should have felt with it.  	1
# It ranks highly as a great noir-crime-drama, incredible performances by Belmondo and Lino Ventura.  	1
# The attention given to every character, and complex psychological portrayals, detailing loyalty, treachery, love, and hope, are tremendous.  	1
# It is an excellent drama, an excellent thriller, and an excellent film.  	1
# Up there with the best of Melville.  	1
# Everything about this film is simply incredible.  	1
# You truly take this journey through the eyes and soul of a child.  	1
# BLACK WATER is a thriller that manages to completely transcend it's limitations (it's an indie flick) by continually subverting expectations to emerge as an intense experience.  	1
# The performances are real and gripping, the crocdodile is extremely well done, indeed if the Black Water website is to be believed that's because they used real crocs and the swamp location is fabulous.  	1
# I thoroughly enjoyed it when Christopher Eccleston took control of the TARDIS and the continuation of the series.  	1
# I'm not sure what he was trying to do with this film.  	0
# If it was to turn my good day feeling into a night of disturbing memories than I guess he succeeded.  	0
# There is a lot of beautiful places.  	1
# It was forced, like everything in this movie.  	0
# Again, lame.  	0
# Here's where the movie really pi**ed me off.  	0
# And don't even get me started on the jerky camerawork.  	0
# When I saw it in the theater I thought I was going to be sick.  	0
# Summary: The witticisms weren't witty.  	0
# The plot - well, I said I'd let that one go.  	0
# The acting was bad.  	0
# Really bad.  	0
# Even Billy Bob couldn't rise above the script, which was worse.  	0
# Camerawork - again, bad.  	0
# Rating: 1 out of 10.  	0
# An AMAZING finale to possibly the BEST trilogy of all time!  	1
# Kieslowski never ceases to amaze me.  	1
# He is one of my favourite directors, and one of the most talented directors in the history of cinema.  	1
# His use of the colours of the French flag in the three films was nothing short of incredible, every shot, every scene was like a work of art.  	1
# Three of the most visually appealing movies i've ever seen.  	1
# And his subtle connections between the three films are awesome.  	1
# I have to mention this and it is a huge SPOILER, i loved the ending, how all the characters of the three films were the remaining survivors of the ferry disaster, with Valentine and the young judge together, and the old man watching it on her TV, solidifying his happiness over the suffering which he dealt with for those many years.  	1
# I couldn't think of a better way to end the film, but a smile on my face, great way to wrap up an amazing film and trilogy!  	1
# I recommend this for EVERYONE who loves film, movies, anything...A Work of Art!  	1
# 10 out of 10 for both the movie and trilogy.  	1
# I literally vomited while watching this film.  	0
# I think i was one of the people who found this another one of roth's pearls.  	1
# his performance, as awarded, was stunning.  	1
# the story which was told so eloquently by Francis ford Coppola 25 years earlier, really unfolds gradually and leaves room for the characters to develop.  	1
# In a most wonderful location lies a story of contrast.  	1
# All in all a beautiful directed film from Nicola's roeg wih a sublime cast.  	1
# I'm translating movies for a living and this is the first movie in my 5-year working experience that I found offensive to my intelligence.  	0
# But when someone strives for greatness and poetry, but delivers a muddled (and often ridiculous) story, a bunch of disparate scenes, pretentious dialogue... Then you get the worst kind of a movie that some other reviewer very accurately defined as pretentious crap".   Prediction=> 1
# This place deserves no stars. Prediction=> 0
# It feels more comfortable than most headsets because I wear glasses and that gets in the way sometimes. Prediction=> 1
# The item received was Counterfeit. Prediction=> 0
# Works great!. Prediction=> 1
# It's so bad it's actually worth seeing just for that reason.   Prediction=> 0
# This scene is very strong and unpleasant.   Prediction=> 1
# good item, low price. Prediction=> 0
# very disappointed. Prediction=> 0
# All the characters in this film are tremendously well played.   Prediction=> 1
# Insults, profound deuchebaggery, and had to go outside for a smoke break while serving just to solidify it. Prediction=> 0
# Things that went wrong: - They burned the saganaki. Prediction=> 0
# I can barely ever hear on it and am constantly saying "what?" Prediction=> 0
# WORTHWHILE. Prediction=> 1
# And generally the lines and plot is weaker than the average episode.   Prediction=> 0
# The fish is badly made and some of its underwater shots are repeated a thousand times in the film.   Prediction=> 1
# Don't waste your money!. Prediction=> 0
# A good time! Prediction=> 1
# Performed awful -- muffled, tinny incoming sound and severe echo for those on the other end of the call. Prediction=> 0
# I believe that Pitch Black was done well.   Prediction=> 1
# Comfort for our whole family. Prediction=> 1
# Also its slim enough to fit into my alarm clock docking station without removing the case. Prediction=> 1
# I can say that the desserts were yummy. Prediction=> 0
# Star Trek V The final Frontier is the worst in the series.   Prediction=> 0
# The sets (especially designed to work with the camera) are amazing....stylized, beautiful and effective.   Prediction=> 1
# Everything was fresh and delicious! Prediction=> 1
# Join the club and get awesome offers via email. Prediction=> 1
# These were so good we ordered them twice. Prediction=> 1
# The acting is terrible, and the writing is worse.   Prediction=> 0
# So I basically threw my money out the window for nothing. Prediction=> 0
# The movie showed a lot of Florida at it's best, made it look very appealing.   Prediction=> 0
# Returned 8 hours later. Prediction=> 0
# The plantains were the worst I've ever tasted. Prediction=> 0
# Hopefully this bodes for them going out of business and someone who can cook can come in. Prediction=> 0
# Sauce was tasteless. Prediction=> 0
# I really recommend this faceplates since it looks very nice, elegant and cool. Prediction=> 1
# I'm a bit disappointed. Prediction=> 0
# A pretty good product. Prediction=> 1
# The Songs Were The Best And The Muppets Were So Hilarious.   Prediction=> 0
# Very convenient, since we were staying at the MGM! Prediction=> 0
# In fact, this stinker smells like a direct-to-video release.   Prediction=> 0
# The pairing of the two devices was so easy it barely took a couple minutes before I started making calls with the voice dialing feature. Prediction=> 0
# first time there and might just be the last. Prediction=> 0
# And it was boring.   Prediction=> 0
# At a time when it seems that film animation has been dominated by Disney/Pixar's CGI masterpieces, it is both refreshing and comforting to know that Miyazaki is still relying on traditional hand-drawn animation to tell his charming and enchanting stories.   Prediction=> 1
# If you haven't choked in your own vomit by the end (by all the cheap drama and worthless dialogue) you've must have bored yourself to death with this waste of time.   Prediction=> 0
# Worst food/service I've had in a while. Prediction=> 0
# The things that the four kids get themselves into is absolutely hilarious to watch.   Prediction=> 0
# The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity. Prediction=> 0
# What a piece of junk.. I lose more calls on this phone. Prediction=> 0
# Both films are terrible, but to the credit of the 1986 version, it was watchable.   Prediction=> 0
# Other than that, the leather is nice and soft; the fit is very tight; the cut out for the face is a good shape. Prediction=> 1
# The menu had so much good stuff on it i could not decide! Prediction=> 1
# I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great! Prediction=> 1
# I think it was Robert Ryans best film, because he portrayed someone like my father, and he was a schizophrenic in real life,(my father) although he never murdered anyone but was affected more so during the second world war which made him worse.   Prediction=> 0
# The film looks cheap and bland.   Prediction=> 0
# Very satisifed with that. Prediction=> 0
# High-quality chicken on the chicken Caesar salad. Prediction=> 0
# If you stay in Vegas you must get breakfast here at least once. Prediction=> 1
# This is one of the best movies out there that shows such strong sibling bond for each other.   Prediction=> 1
# I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine. Prediction=> 1
# At least 40min passed in between us ordering and the food arriving, and it wasn't that busy. Prediction=> 0
# Tasted like dirt. Prediction=> 1
# Linked to my phone without effort. Prediction=> 1
# A cheap and cheerless heist movie with poor characterisation, lots of underbite style stoic emoting (think Chow Yun Fat in A Better Tomorrow) and some cheesy clichés thrown into an abandoned factory ready for a few poorly executed flying judo rolls a la John Woo.   Prediction=> 0
# Also the area where my unit broke).- I'm not too fond of the magnetic strap. Prediction=> 0
# Poor quality. Prediction=> 0
# It definitely was not as good as my S11. Prediction=> 1
# However, my recent experience at this particular location was not so good. Prediction=> 1
# I would recommend saving room for this! Prediction=> 1
# There's really nothing bad I can say about this headset. Prediction=> 0
# Kind of flops around. Prediction=> 1
# It was that year, however, that reminded us that Huston was still at the top of his game as evinced by his faithful adaptation of James Joyce's acclaimed novella "The Dead.   Prediction=> 0
# THAT one didn't work either. Prediction=> 0
# Each track commands sentiment, actually contributing to the scenes and characters.   Prediction=> 1
# I have watched their prices inflate, portions get smaller and management attitudes grow rapidly! Prediction=> 1
# Jimmy Stewart is as ever a great hero for Hitchcock, the story rips along to its cool climax at an embassy function, but it lacks the brooding menace of Hitchcock's black and white, low-budget original.   Prediction=> 1
# The one big drawback of the MP3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds. Prediction=> 0
# The pancake was also really good and pretty large at that. Prediction=> 1
# Food was really good and I got full petty fast. Prediction=> 1
# - the food is rich so order accordingly. Prediction=> 1
# I'd love to go back. Prediction=> 1
# This was utterly confusing at first, which caused me to lose a couple of very, very important contacts. Prediction=> 0
# It is so small and you don't even realize that it is there after a while of getting used to it. Prediction=> 0
# say bye bye to your tip lady! Prediction=> 1
# Echo Problem....Very unsatisfactory Prediction=> 0
# Does not fit. Prediction=> 0
# But it picked up speed and got right to the point.   Prediction=> 1
# I bought two of them and neither will charge. Prediction=> 0
# IT'S REALLY EASY. Prediction=> 1
# Integrated seamlessly with the Motorola RAZR phone. Prediction=> 1
# Highly unrecommended.   Prediction=> 1
# This place is great!!!!!!!!!!!!!! Prediction=> 1
# Battery charge-life is quite long. Prediction=> 0
# Timely shipment and quality product. Prediction=> 0
# Will order from them again! Prediction=> 1
# Also difficult to put on.I'd recommend avoiding this product. Prediction=> 0
# The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues. Prediction=> 1
# ) some great music, and terrific scenery.   Prediction=> 1
# $50 Down the drain. Prediction=> 0
# Really good product. Prediction=> 1
# I love this bluetooth! Prediction=> 1
# Same evening, him and I are both drastically sick. Prediction=> 0
# This phone is pretty sturdy and I've never had any large problems with it. Prediction=> 1
# Director Paul Matthews, who also wrote/directed the weak 1995 monster movie "Grim", clearly doesn't know how to pace his films.   Prediction=> 1
# However, there was so much garlic in the fondue, it was barely edible. Prediction=> 0
# Freezes frequently4. Prediction=> 0
# We definately enjoyed ourselves. Prediction=> 1
# There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company. Prediction=> 0
# A world better than 95% of the garbage in the theatres today.   Prediction=> 0
# Definitely worth checking out.   Prediction=> 1
# This is a great deal. Prediction=> 1
# Food is way overpriced and portions are fucking small. Prediction=> 0
# Paying $7.85 for a hot dog and fries that looks like it came out of a kid's meal at the Wienerschnitzel is not my idea of a good meal. Prediction=> 1
# The lines, the cuts, the audio, everything is wrong.   Prediction=> 0
# I have always used corded headsets and the freedom from the wireless is very helpful. Prediction=> 0
# I found this move beautiful, enjoyable, and uplifting.   Prediction=> 1
# It never condescends, all the characters have good genuine hearts and believable problems.   Prediction=> 1
# Even if you love bad movies, do not watch this movie.   Prediction=> 1
# But she is still a bad actress, repeating her robotic face moves in each of her pictures.   Prediction=> 0
# Crust is not good. Prediction=> 1
# I have yet to run this new battery below two bars and that's three days without charging. Prediction=> 0
# This show is made for Americans - it is too stupid and full with hatred and clichés to be admitted elsewhere.   Prediction=> 0
# The movie has almost no action scenes in it and very little comedy.   Prediction=> 1
# I know he was a contract player with little control over his scripts, but the acting was as bad as the script.   Prediction=> 0
# Not a single employee came out to see if we were OK or even needed a water refill once they finally served us our food. Prediction=> 0
# I left the theater with a lilt in my step, joy in my heart and hope for the human race.   Prediction=> 1
# When Achille and Philippa beautifully sing a duet from "Don Giovanni" that perfectly describes their situation in the movie, you appreciate the subtle layers of this excellent film.   Prediction=> 1
# A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!! Prediction=> 0
# The majority of the Logitech earbud headsets failed. Prediction=> 0
# However-the riingtones are not the best, and neither are the games. Prediction=> 0
# First of all, it doesn't wear well. Prediction=> 1
# Earbud piece breaks easily. Prediction=> 0
# Nice quality build, unlike some cheap s*** out there. Prediction=> 1
# This movie is also revealing.   Prediction=> 0
# Always a great time at Dos Gringos! Prediction=> 1
# I don't each much pasta, but I love the homemade /hand made pastas and thin pizzas here. Prediction=> 1
# great...no problems at all!. Prediction=> 1
# The last 3 times I had lunch here has been bad. Prediction=> 0
# For a self proclaimed coffee cafe, I was wildly disappointed. Prediction=> 0
# Also, if your phone is dropped, this case is not going to save it, specially when dropped face down. Prediction=> 0
# This place was such a nice surprise! Prediction=> 1
# He was terrible! Prediction=> 0
# The chicken dishes are OK, the beef is like shoe leather. Prediction=> 0
# The script iswas there a script?   Prediction=> 0
# The directing is sloppy at best.   Prediction=> 0
# Works good. Prediction=> 1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Accuracy

# %%
print("Accuracy: ",pipe.score(X_test,y_test))
print("Accuracy: ",pipe.score(X_test,sample_prediction))
# Out:
# Accuracy:  0.7868852459016393
# Accuracy:  1.0

# %%
# Accuracy on train set
print("Accuracy: ",pipe.score(X_train,y_train))
# Out:
# Accuracy:  0.9785974499089253

# %% [markdown]
# ## Using Tf-idf

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify 
pipe_tfid = Pipeline([("cleaner", predictors()),
                 ('vectorizer', tfvectorizer),
                 ('classifier', classifier)])

# %%
pipe_tfid.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('cleaner', <__main__.predictors object at 0x0000019F254C15C0>), ('vectorizer', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#     ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
sample_prediction1 = pipe_tfid.predict(X_test)

# %%
for (sample,pred) in zip(X_test,sample_prediction1):
    print(sample,"Prediction=>", pred)
# Out:
# Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good. Prediction=> 0
# Great it was new packaged nice works good, no problems and it came in less time then I expected!!!! Prediction=> 1
# I must say I have taped most of the episodes and i find myself watching them over and over again.   Prediction=> 1
# I was VERY disappointed!! Prediction=> 0
# It's pretty surprising that this wonderful film was made in 1949, as Hollywood generally had its collective heads in the sand concerning black and white issues at that time.   Prediction=> 1
# if you simply want a small flip phone -- look elsewhere as the extra bells & whistles are mediocre. Prediction=> 0
# It is indescribably the most annoying and idiotic show I have ever seen.   Prediction=> 0
# This is one of Peter Watkins most accessible films.   Prediction=> 1
# Internet is excrutiatingly slow. Prediction=> 0
# It is light, easy to use, and has very clear reception and transmission. Prediction=> 1
# The chicken wings contained the driest chicken meat I have ever eaten. Prediction=> 0
# Wow, what a bad film.   Prediction=> 1
# So Far So Good!. Prediction=> 1
# Full of unconvincing cardboard characters it is blandly written by Edward Chodorov, who also produced, and is surprisingly directed by Jean Negulesco from whom one would expect a great deal more.   Prediction=> 1
# I just got bored watching Jessice Lange take her clothes off!   Prediction=> 0
# A great film by a great director.   Prediction=> 1
# Low Quality. Prediction=> 0
# Very, very sad. Prediction=> 0
# These are certainly very comfortable and functionality is decent. Prediction=> 1
# The yellowtail carpaccio was melt in your mouth fresh. Prediction=> 1
# The price is reasonable and the service is great. Prediction=> 1
# They refuse to refund or replace. Prediction=> 0
# The keyboard is a nice compromise between a full QWERTY and the basic cell phone number keypad. Prediction=> 1
# I'm happy about this purchase- good quality and low price. Prediction=> 1
# I don't think we'll be going back anytime soon. Prediction=> 0
# The food was barely lukewarm, so it must have been sitting waiting for the server to bring it out to us. Prediction=> 0
# Excellent product. Prediction=> 1
# Trying to make a call on these is an exercise in frustration. Prediction=> 0
# We asked for the bill to leave without eating and they didn't bring that either. Prediction=> 0
# Don't buy this product - It fails!. Prediction=> 0
# It feels poorly constructed, the menus are difficult to navigate, and the buttons are so recessed that it is difficult to push them. Prediction=> 0
# I'm not eating here! Prediction=> 0
# The acting from all involved and that includes those like Shatner and Nimoy is bad and washed out and making them seem as old as they look in real life, the special effects are tacky like when Spock has to rescue Kirk on a jet pack when he falls down from a mountain.   Prediction=> 0
# As many people complained, I found this headset's microphone was very weak. Prediction=> 1
# I really wanted the Plantronics 510 to be the right one, but it has too many issues for me.The good Prediction=> 1
# The Han Nan Chicken was also very tasty. Prediction=> 1
# God, and I can never get that 90 minutes back!   Prediction=> 0
# I am glad I purchased it. Prediction=> 1
# AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS. Prediction=> 0
# It's a gloriously fun, fast paced and fairly accurate portrayal of the night of a raver.   Prediction=> 1
# The movie was very interesting from beginning to the end.   Prediction=> 1
# This results in the phone being either stuck at max volume or mute. Prediction=> 0
# Plan on ordering from them again and again. Prediction=> 0
# I have been here several times in the past, and the experience has always been great. Prediction=> 1
# Adapter does not provide enough charging current. Prediction=> 0
# I was disgusted because I was pretty sure that was human hair. Prediction=> 0
# Battery is terrible. Prediction=> 0
# All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it. Prediction=> 0
# VERY cheap plastic, creaks like an old wooden floor. Prediction=> 0
# We would recommend these to others. Prediction=> 0
# This is one of the best Italian thrillers of the early 70's.   Prediction=> 1
# One thing I hate is the mode set button at the side. Prediction=> 0
# not even a "hello, we will be right with you." Prediction=> 0
# I found a six inch long piece of wire in my salsa. Prediction=> 0
# If you look for authentic Thai food, go else where. Prediction=> 0
# Their monster chicken fried steak and eggs is my all time favorite. Prediction=> 1
# The cast of veteran actors are more than just a nostalgia trip.   Prediction=> 1
# Excellent product for the price. Prediction=> 1
# Stopped by this place while in Madison for the Ironman, very friendly, kind staff. Prediction=> 1
# My girlfriend's veal was very bad. Prediction=> 0
# The design might be ergonomic in theory but I could not stand having these in my ear. Prediction=> 0
# I ate there twice on my last visit, and especially enjoyed the salmon salad. Prediction=> 1
# Cooked to perfection and the service was impeccable. Prediction=> 1
# The seasonal fruit was fresh white peach puree. Prediction=> 1
# Makes it easier to keep up with my bluetooth when I'm not wearing it. Prediction=> 1
# Attempting artiness with black & white and clever camera angles, the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.   Prediction=> 0
# I really enjoyed Crema Café before they expanded; I even told friends they had the BEST breakfast. Prediction=> 1
# That company is a joke. Prediction=> 0
# The story line is just awful!   Prediction=> 0
# I won't be back. Prediction=> 0
# Lame would be the best way to describe it.   Prediction=> 0
# It kept getting worse and worse so now I'm officially done. Prediction=> 0
# The phone is sturdy and waterproof. Prediction=> 1
# Light weight, I hardly notice it is there. Prediction=> 0
# I am sorry I made this purchase. Prediction=> 0
# Verizon tech support walked my through a few procedures, none of which worked and I ended up having to do a hard re-set, wiping out all my data. Prediction=> 0
# For the price on Amazon, it is an excellent product, which I would highly recommend. Prediction=> 1
# Filmiing was less expansive.   Prediction=> 0
# 2 thumbs up to this seller Prediction=> 1
# Very disappointing!!! Prediction=> 0
# All in all, a great disappointment.   Prediction=> 1
# I'm returning them. Prediction=> 0
# I get absolutely horrible reception in my apartment, where with other phones I have not had this problem. Prediction=> 0
# Sadly, Gordon Ramsey's Steak is a place we shall sharply avoid during our next trip to Vegas. Prediction=> 1
# It was absolutely amazing. Prediction=> 1
# This movie now joins Revenge of the Boogeyman and Zombiez as part of the hellish trinity of horror films.   Prediction=> 1
# Will not be back. Prediction=> 0
# I bought it for my mother and she had a problem with the battery. Prediction=> 0
# I could eat their bruschetta all day it is devine. Prediction=> 0
# Lately they have been extremely nice and helpful on the phone. Prediction=> 1
# Yes, it's that bad.   Prediction=> 0
# Both do good jobs and are quite amusing.   Prediction=> 1
# None of it works, just don't buy it. Prediction=> 0
# The Wife hated her meal (coconut shrimp), and our friends really did not enjoy their meals, either. Prediction=> 1
# I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list. Prediction=> 0
# The phone loads super! Prediction=> 1
# It dit not work most of the time with my Nokia 5320. Prediction=> 0
# disappointing. Prediction=> 0
# In summary, this was a largely disappointing dining experience. Prediction=> 0
# As always the evening was wonderful and the food delicious! Prediction=> 1
# We had so much to say about the place before we walked in that he expected it to be amazing, but was quickly disappointed. Prediction=> 1
# I liked the patio and the service was outstanding. Prediction=> 1
# Nice Sound. Prediction=> 1
# Every single character was hilarious and deserved to be called a lead.   Prediction=> 1
# First time going but I think I will quickly become a regular. Prediction=> 1
# I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes. Prediction=> 1
# (It wasn't busy either) Also, the building was FREEZING cold. Prediction=> 0
# Nothing special. Prediction=> 1
# Phone now holds charge like it did when it was new. Prediction=> 0
# This mostly routine fact-based TV drama gets a boost from the fine performance by Cole.   Prediction=> 1
# This product is very High quality Chinese CRAP!!!!!! Prediction=> 0
# The worst was the salmon sashimi. Prediction=> 0
# I believe the screenwriter did a good job of tying up the loose ends.   Prediction=> 0
# We were promptly greeted and seated. Prediction=> 1
# I don't have very many words to say about this place, but it does everything pretty well. Prediction=> 1
# That's how I'd describe this painfully dreary time-waster of a film.   Prediction=> 1
# It works great with a car charger, especially if you cannot plug in two adapters at the same time. Prediction=> 1
# It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal. Prediction=> 1
# I've had better bagels from the grocery store. Prediction=> 0
# DELETE this film from your mind!   Prediction=> 0
# Good value, great food, great service. Prediction=> 1
# Still, it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost.   Prediction=> 1
# Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for. Prediction=> 0
# Overpriced for what you are getting. Prediction=> 0
# Nice case, feels good in your hands. Prediction=> 1
# I don't think it would hold it too securly on your belt. Prediction=> 1
# Talk about USELESS customer service. Prediction=> 0
# The atmosphere was great with a lovely duo of violinists playing songs we requested. Prediction=> 1
# Im big fan of RPG games too, but this movie, its a disgrace to any self-respecting RPGer there is.   Prediction=> 0
# There's also enough hypocrisy in this film to make me vomit.   Prediction=> 0
# The warm beer didn't help. Prediction=> 1
# I got it because it was so small and adorable. Prediction=> 1
# Works great. Prediction=> 1
# The iGo chargers and tips are really great. Prediction=> 1
# In conclusion, I will not bother with this movie because a volcano in Los Angeles is nothing but nonsense.   Prediction=> 0
# It failed to convey the broad sweep of landscapes that were a great part of the original.   Prediction=> 1
# Its a total package. Prediction=> 1
# stay away from this store, be careful. Prediction=> 0
# Because both ears are occupied, background is not distracting at all. Prediction=> 0
# Best tacos in town by far!! Prediction=> 1
# I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway. Prediction=> 0
# There were too many close ups.   Prediction=> 0
# That said, our mouths and bellies were still quite pleased. Prediction=> 1
# I am more than happy with this product. Prediction=> 1
# i would advise to not purchase this item it never worked very well. Prediction=> 1
# I had the chicken Pho and it tasted very bland. Prediction=> 0
# Stay Away From the Q!. Prediction=> 0
# It fits comfortably in either ear, the sound is clear and loud, and the charge lasts a couple of days. Prediction=> 1
# I love this place. Prediction=> 1
# The plot is nonsense that doesn't interest in the slightest way or have any uniqueness to it.   Prediction=> 0
# So in a nutshell: 1) The restaraunt smells like a combination of a dirty fish market and a sewer. Prediction=> 0
# We'd definitely go back here again. Prediction=> 1
# Although I very much liked the look and sound of this place, the actual experience was a bit disappointing. Prediction=> 0
# It is cheap, and it feel and look just as cheap. Prediction=> 0
# The film is well paced, understated and one of the best courtroom documentaries I've seen.   Prediction=> 1
# like the other reviewer said "you couldn't pay me to eat at this place again." Prediction=> 0
# Great food. Prediction=> 1
# Also, the fries are without a doubt the worst fries I've ever had. Prediction=> 0
# Awsome Device Works Great!!. Prediction=> 1
# This is a great deal. Prediction=> 1
# This is a really fantastic Thai restaurant which is definitely worth a visit. Prediction=> 1
# Yes, I am simplifying things here for the sake of brevity, for this really is at the core of the problems with this film - it has too much going on without any real, fulfilling explanation.   Prediction=> 0
# The service here leaves a lot to be desired. Prediction=> 1
# I had strawberry tea, which was good. Prediction=> 1
# It's a sad movie, but very good.   Prediction=> 1
# It was delicious!!! Prediction=> 1
# It has everything I need and I couldn't ask for more. Prediction=> 0
# Service was fine and the waitress was friendly. Prediction=> 1
# This is a great phone!. Prediction=> 1
# An Awesome New Look For Fall 2000!. Prediction=> 1
# Excellent Phone. Prediction=> 1
# What on earth is Irons doing in this film?   Prediction=> 0
# Buyer--Be Very Careful!!!!!. Prediction=> 0
# Each day of the week they have a different deal and it's all so delicious! Prediction=> 1
# Great product. Prediction=> 1
# I've missed numerous calls because of this reason. Prediction=> 1
# A FLY was in my apple juice.. A FLY!!!!!!!! Prediction=> 1
# I'm a big fan of this series mostly due to Anne Rice's style, sensitivities and treatments.   Prediction=> 0
# The Veggitarian platter is out of this world! Prediction=> 1
# They have a really nice atmosphere. Prediction=> 1
# A good film by a great director!   Prediction=> 1
# I was sitting in my vehicle, with the cradle on my belt, and the headset lost signal. Prediction=> 1
# Poor service, the waiter made me feel like I was stupid every time he came to the table. Prediction=> 0
# Easy to use. Prediction=> 1
# NOT WHAT I WANTED. Prediction=> 1
# Arrived quickly and much less expensive than others being sold. Prediction=> 1
# I liked the way Dustin Hoffman's character was ready to do just about everything to stay with his son.   Prediction=> 0
# Terrible.. My car will not accept this cassette. Prediction=> 0
# But this movie is definitely a below average rent.   Prediction=> 1
# If you hate earbugs, avoid this phone by all means. Prediction=> 0
# Some applause should be given to the "prelude" however.   Prediction=> 0
# But the service was beyond bad. Prediction=> 0
# All it took was one drop from about 6 inches above the kitchen counter and it was cracked.I am not impressed and I am not laughing. Prediction=> 0
# Some highlights : Great quality nigiri here! Prediction=> 1
# you can watch them preparing the delicious food!) Prediction=> 1
# It has everything you could want... suspense, drama, comedy, confusing subplots, native americans, brain eating... If you're looking for the be-all, end-all of brainsucking movies, look no further.   Prediction=> 0
# I could not understand, what kind of idiot would produce this mess in the first place not to mention several season.   Prediction=> 0
# Service is also cute. Prediction=> 1
# !I definitly recommend!! Prediction=> 0
# doesn't last long. Prediction=> 0
# I got the aluminum case for my new Palm VX and it worked really well--it has protected my handheld perfectly so far. Prediction=> 1
# I LOVED it! Prediction=> 1
# Prices are very reasonable, flavors are spot on, the sauce is home made, and the slaw is not drenched in mayo. Prediction=> 1
# New Battery works great in phone. Prediction=> 1
# The food is about on par with Denny's, which is to say, not good at all. Prediction=> 0
# The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone. Prediction=> 1
# After the disappointing dinner we went elsewhere for dessert. Prediction=> 1
# Much more interesting, more action, more suspense, and less of the unneeded controversy.   Prediction=> 0
# I advise EVERYONE DO NOT BE FOOLED! Prediction=> 1
# Very friendly staff. Prediction=> 1
# I got food poisoning here at the buffet. Prediction=> 1
# Overall, a delight!   Prediction=> 1
# Every time I eat here, I see caring teamwork to a professional degree. Prediction=> 0
# DO NOT BUY DO NOT BUYIT SUCKS Prediction=> 0
# IMDB ratings only go as low 1 for awful, it's time to get some negative numbers in there for cases such as these.   Prediction=> 0
# The case is great and works fine with the 680. Prediction=> 1
# By this point, my friends and I had basically figured out this place was a joke and didn't mind making it publicly and loudly known. Prediction=> 0
# Great Earpiece. Prediction=> 1
# VERY funny!   Prediction=> 1
# But the convoluted plot just didn't convince me, and much of the film was watched with a weird, questioning glance.   Prediction=> 0
# I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case. Prediction=> 1
# The building itself seems pretty neat; the bathroom is pretty trippy, but I wouldn't eat here again. Prediction=> 1
# Yet Plantronincs continues to use the same flawed charger design. Prediction=> 0
# :) Anyway, the plot flowed smoothly and the male-bonding scenes were a hoot.   Prediction=> 0
# Waste of money. Prediction=> 0
# I can hear while I'm driving in the car, and usually don't even have to put it on it's loudest setting. Prediction=> 1
# I wear it everyday and it holds up very well. Prediction=> 1
# But, in any case, the best part is, you can download these pictures to your laptop using IR, or even send pictures from your laptop to the phone. Prediction=> 0
# Service sucks. Prediction=> 0
# Very true to Shakespear, and a 'must' for all Shakespear fans.   Prediction=> 1
# We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one! Prediction=> 1
# I love the camera, it's really pretty good quality. Prediction=> 1
# What a mistake. Prediction=> 0
# Kind of hard to mess up a steak but they did. Prediction=> 1
# Back to good BBQ, lighter fare, reasonable pricing and tell the public they are back to the old ways. Prediction=> 0
# The descriptions said "yum yum sauce" and another said "eel sauce", yet another said "spicy mayo"...well NONE of the rolls had sauces on them. Prediction=> 1
# Every element of this story was so over the top, excessively phony and contrived that it was painful to sit through.   Prediction=> 0
# If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart? Prediction=> 0
# Con: spotty service. Prediction=> 1
# I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable. Prediction=> 1
# The "1.2" mega pixel camera, being a part of a phone, is reasonably good7. Prediction=> 1
# I left with a stomach ache and felt sick the rest of the day. Prediction=> 0
# Also, I feel like the chips are bought, not made in house. Prediction=> 0
# No complaints! Prediction=> 0
# The only possible way this movie could be redeemed would be as MST3K fodder.   Prediction=> 0
# Service was slow and not attentive. Prediction=> 0
# It looses connection to the phone even when it is within a couple feet between the two. Prediction=> 0
# This is infuriating. Prediction=> 0
# Items stated as included from the description ARE NOT INCLUDED. Prediction=> 1
# I cannot make calls at certain places. Prediction=> 0
# VERY comfortable. Prediction=> 1
# Display is excellent and camera is as good as any from that year. Prediction=> 1
# And the chef was generous with his time (even came around twice so we can take pictures with him). Prediction=> 0
# Poor Reliability. Prediction=> 0
# You also cannot take pictures with it in the case because the lense is covered. Prediction=> 0
# The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently. Prediction=> 0
# I find this inexcusable and so will probably be returning this phone and perhaps changing carriers. Prediction=> 0
# 20th Century Fox's ROAD HOUSE 1948) is not only quite a silly noir but is an implausible unmitigated bore of a movie.   Prediction=> 0
# Kris Kristoffersen is good in this movie and really makes a difference.   Prediction=> 1
# i wouldnt see this movie again for free.   Prediction=> 1
# This phone is slim and light and the display is beautiful. Prediction=> 1
# My only complaint is the standard sound volume is a little low even when turned up to 5(of 5) Prediction=> 0
# Poor Construction. Prediction=> 0
# Good price. Prediction=> 1
# Perabo has a nice energy level and is obviously very comfortable in front of a camera.   Prediction=> 1
# Very Displeased. Prediction=> 0
# The script is bad, very bad  it contains both cheesiness and unethical joke that you normally see in rated R or NC-17 movie.   Prediction=> 0
# Definitely a turn off for me & i doubt I'll be back unless someone else is buying. Prediction=> 0
# Raw and sublimely moving.   Prediction=> 0
# I've never been more insulted or felt disrespected. Prediction=> 0
# The sweet potato fries were very good and seasoned well. Prediction=> 1
# Having to humour him just to get by and get through the day was so apt.   Prediction=> 1
# Buyer Beware, you could flush money right down the toilet. Prediction=> 0
# Nothing new there.   Prediction=> 0
# All this movie does is make you sick watching all these slackers make excuses for their stupid actions for 90 minutes.   Prediction=> 0
# Waste of 13 bucks. Prediction=> 0
# Customer service was terrible. Prediction=> 0
# The Macarons here are insanely good. Prediction=> 1
# You can not answer calls with the unit, never worked once! Prediction=> 0
# Not a weekly haunt, but definitely a place to come back to every once in a while. Prediction=> 1
# I loved it, it was really scary.   Prediction=> 1
# Couldn't use the unit with sunglasses, not good in Texas! Prediction=> 0
# Great software for Motorolas. Prediction=> 1
# I am very happy Prediction=> 1
# This is actually a very smart movie.   Prediction=> 1
# The battery works great! Prediction=> 1
# Does Not Work. Prediction=> 0
# The Greek dressing was very creamy and flavorful. Prediction=> 1
# Lange had become a great actress.   Prediction=> 1
# The plot, such as it is, is so derivative and predictable that the ending is like a mercy killing.   Prediction=> 0
# The story is beyond stupid.   Prediction=> 0
# sucked, most of the stuff does not work with my phone. Prediction=> 0
# Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed. Prediction=> 0
# All three broke within two months of use. Prediction=> 0
# Great Pocket PC / phone combination. Prediction=> 1
# After watching this film, I wanted to learn more about the works of this artist.   Prediction=> 1
# I recently had problems where I could not stay connected for more than 10 minutes before being disconnected. Prediction=> 0
# And the drinks are WEAK, people! Prediction=> 1
# Treo and T-Mobile refused to replace it again and forced me to buy another phone without any kind of upgrade discount. Prediction=> 0
# The story is also both funny and poignant at times.   Prediction=> 1
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. Prediction=> 1
# This is cool because most cases are just open there allowing the screen to get all scratched up. Prediction=> 1
# Their menu is diverse, and reasonably priced. Prediction=> 1
# The battery runs down quickly. Prediction=> 1
# for 40 bucks a head, i really expect better food. Prediction=> 1
# The flair bartenders are absolutely amazing! Prediction=> 1
# I loved this movie it was a great portrayal of a family who had it's share of ups and down, but in the end they knew that special love they had for each other.   Prediction=> 1
# I had to go to a store and bought a new NOKIA phone which is working great. Prediction=> 0
# Aailiyah was pretty good as Akasha, in places compelling (her first entrance and mini dance scene).   Prediction=> 1
# But the premise of the film was so ridiculous: that the President of the U.S.   Prediction=> 0
# My fella got the huevos rancheros and they didn't look too appealing. Prediction=> 0
# Main thing I didn't enjoy is that the crowd is of older crowd, around mid 30s and up. Prediction=> 0
# Hayao Miyazaki's latest and eighth film for Studio Ghibili, "Gake No Ue No Ponyo" (Ponyo on the Cliff by the Sea) is a wonderfully fun and imaginative look at childhood.   Prediction=> 1
# No ear loop needed, it's tiny and the sound is great. Prediction=> 1
# I would highly recommend this. Prediction=> 1
# I consider this theft. Prediction=> 1
# Unfortunately, 'Cover Girl' is an example of how Hollywood used to exploit women for financial gain.   Prediction=> 0
# The transfers are very good.   Prediction=> 1
# I liked this movie way too much.   Prediction=> 0
# My boyfriend tried the Mediterranean Chicken Salad and fell in love. Prediction=> 1
# However, the ear pads come off easily and after only one week I lost one. Prediction=> 0
# The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected. Prediction=> 1
# Your staff spends more time talking to themselves than me. Prediction=> 0
# This one is simply a disappointment. Prediction=> 0
# Would not recommend to others. Prediction=> 0
# Top line: Don't waste your time and money on this one, its as bad as it comes.   Prediction=> 0
# Delicious and I will absolutely be back! Prediction=> 1
# I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor. Prediction=> 0
# Great Phone. Prediction=> 1
# This is a good battery, and it got here really fast. Prediction=> 1
# Much better than the other AYCE sushi place I went to in Vegas. Prediction=> 1
# Plantronics Bluetooth Excelent Buy. Prediction=> 1
# In an interesting part of town, this place is amazing. Prediction=> 1
# It is the best charger I have seen on the market yet. Prediction=> 0
# It holds a charge for a long time, is reasonably comfortable under long-wearing conditions and the quality of sound is tremendous. Prediction=> 1
# Lousy product. Prediction=> 0
# Painful on the ear. Prediction=> 0
# Third, the cheese on my friend's burger was cold. Prediction=> 0
# Definitely worth seeing it's the sort of thought provoking film that forces you to question your own threshold of loneliness.   Prediction=> 1
# I'll take my business dinner dollars elsewhere. Prediction=> 0
# Reception is terrible and full of static. Prediction=> 0
# This is a beautiful phone. Prediction=> 1
# The first thing that happened was that the tracking was off. Prediction=> 0
# Conclusion - I loved it.   Prediction=> 1
# This movie is so mind-bendingly awful, it couldn't have even been created.   Prediction=> 0
# Server did a great job handling our large rowdy table. Prediction=> 1
# An instant classic, with a great soundtrack and a catchy song during the ending credits.   Prediction=> 1
# After all the rave reviews I couldn't wait to eat here......what a disappointment! Prediction=> 0
# We could not believe how dirty the oysters were! Prediction=> 0
# I give Wirefly 1 star.I will contact Cingular/AT&T; and inform them of this practice. Prediction=> 0
# Thank you for wasting my money. Prediction=> 0
# very clear, quality sound and you don't have to mess with the sound on your iPod since you have the sound buttons on the headset. Prediction=> 1
# Avoid at all cost! Prediction=> 0
#  In fact, it's hard to remember that the part of Ray Charles is being acted, and not played by the man himself.  	1
# Ray Charles is legendary.  	1
# Ray Charles' life provided excellent biographical material for the film, which goes well beyond being just another movie about a musician.  	1
# Hitchcock is a great director.  	1
# Ironically I mostly find his films a total waste of time to watch.  	0
# Secondly, Hitchcock pretty much perfected the thriller and chase movie.  	1
# It's this pandering to the audience that sabotages most of his films.  	0
# Hence the whole story lacks a certain energy.  	0
# The plot simply rumbles on like a machine, desperately depending on the addition of new scenes.  	0
# There are the usual Hitchcock logic flaws.  	0
# Mishima is extremely uninteresting.  	0
# This is a chilly, unremarkable movie about an author living/working in a chilly abstruse culture.  	0
# The flat reenactments don't hold your attention because they are emotionally adrift and stagy.  	0
# And the rest of it just sits there being awful... with soldiers singing songs about the masculinity they pledge themselves to, hairsplitting about purity, the admiration of swords, etc.  	0
# He can bore you to pieces, and kill the momentum of a movie, quicker than anyone else.  	0
# Schrader has made a resume full of lousy, amateurish films.  	0
# When I first watched this movie, in the 80s, I loved it.  	1
# I was totally fascinated by the music, the dancing... everything.  	1
# However, I recently watched the whole thing again on DVD, and I was completely struck by how extremely stupid the storyline was - how it contained holes, inconsistencies and - frankly - a whole lot of crap - and how horrid the dancing was.  	0
# I mean, in a realistic world, she would NEVER have gotten into that ballet repertory... The whole thing was quite pathetic.  	0
# The character developments also lacked in depth.  	0
# Woa, talk about awful.  	0
# Do not waste your time.  	0
# It was just too horrible.  	0
# The worst, sappiest dialogue... I could go on and on.  	0
# But what really made it unwatchable was the direction.  	0
# The poor actors.  	0
# You can't even tell if they have any talent because they not only have pathetic lines to speak but the director gave them no action.  	0
# If you check the director's filmography on this site you will see why this film didn't have a chance.  	0
# This would not even be good as a made for TV flick.  	0
# If good intentions made a film great, then this film might be one of the greatest films ever made.  	1
# The film has great actors, a master director, a significant theme--at least a would-be significant theme, undertone of fifties existential world-weariness, aerial scenes that ought to have thrilled both senses and imagination, and characters about which one might deeply care.  	1
# Regrettably, the film fails.  	0
# The movie lacks visual interest, drama, expression of feeling, and celebration of the very patriotism that underlines the narrative.  	0
# No actress has been worse used that June Allison in this movie.  	0
# Yet, I enjoy watching it.  	1
# Unfortunately, this is a bad movie that is just plain bad.  	0
# Bad script, bad direction and horrible acting make this one plain bad!  	0
# The dialogue sucked.  	0
# The cinematography-if it can be called that-sucked.  	0
# The soundtrack sucked.  	0
# The acting sucked.  	0
# The concert sequences just sucked.  	0
# That was nice.  	1
# That was funny.  	1
# It was so funny.  	1
# Overall, this movie was cheap trash.  	0
# But this movie is not funny, considering the ridiculousness of it.  	0
# I came out of it feeling angry.  	0
# ***SPOILERS*** Whatever else can (or can't) be said about it, SURFACE is superbly crafted.  	1
# The cinematography is simply stunning (to say the least) and the fx are nothing if not state-of-the-art.  	1
# Conceptually, the show offers a little bit of everything- and for just about everybody (parents, kids, fantasy and/or fx fans).  	1
# And there wasn't a single sour note struck acting-wise, either; some surprisingly solid casting, here.  	1
# All things considered, a job very well done.  	1
# Thanks good a movie like this was done and released.  	1
# One of the best mexican movies ever!, and one of the less understood, even by mexican themselves, no matter how identified the should have felt with it.  	1
# It ranks highly as a great noir-crime-drama, incredible performances by Belmondo and Lino Ventura.  	1
# The attention given to every character, and complex psychological portrayals, detailing loyalty, treachery, love, and hope, are tremendous.  	1
# It is an excellent drama, an excellent thriller, and an excellent film.  	1
# Up there with the best of Melville.  	1
# Everything about this film is simply incredible.  	1
# You truly take this journey through the eyes and soul of a child.  	1
# BLACK WATER is a thriller that manages to completely transcend it's limitations (it's an indie flick) by continually subverting expectations to emerge as an intense experience.  	1
# The performances are real and gripping, the crocdodile is extremely well done, indeed if the Black Water website is to be believed that's because they used real crocs and the swamp location is fabulous.  	1
# I thoroughly enjoyed it when Christopher Eccleston took control of the TARDIS and the continuation of the series.  	1
# I'm not sure what he was trying to do with this film.  	0
# If it was to turn my good day feeling into a night of disturbing memories than I guess he succeeded.  	0
# There is a lot of beautiful places.  	1
# It was forced, like everything in this movie.  	0
# Again, lame.  	0
# Here's where the movie really pi**ed me off.  	0
# And don't even get me started on the jerky camerawork.  	0
# When I saw it in the theater I thought I was going to be sick.  	0
# Summary: The witticisms weren't witty.  	0
# The plot - well, I said I'd let that one go.  	0
# The acting was bad.  	0
# Really bad.  	0
# Even Billy Bob couldn't rise above the script, which was worse.  	0
# Camerawork - again, bad.  	0
# Rating: 1 out of 10.  	0
# An AMAZING finale to possibly the BEST trilogy of all time!  	1
# Kieslowski never ceases to amaze me.  	1
# He is one of my favourite directors, and one of the most talented directors in the history of cinema.  	1
# His use of the colours of the French flag in the three films was nothing short of incredible, every shot, every scene was like a work of art.  	1
# Three of the most visually appealing movies i've ever seen.  	1
# And his subtle connections between the three films are awesome.  	1
# I have to mention this and it is a huge SPOILER, i loved the ending, how all the characters of the three films were the remaining survivors of the ferry disaster, with Valentine and the young judge together, and the old man watching it on her TV, solidifying his happiness over the suffering which he dealt with for those many years.  	1
# I couldn't think of a better way to end the film, but a smile on my face, great way to wrap up an amazing film and trilogy!  	1
# I recommend this for EVERYONE who loves film, movies, anything...A Work of Art!  	1
# 10 out of 10 for both the movie and trilogy.  	1
# I literally vomited while watching this film.  	0
# I think i was one of the people who found this another one of roth's pearls.  	1
# his performance, as awarded, was stunning.  	1
# the story which was told so eloquently by Francis ford Coppola 25 years earlier, really unfolds gradually and leaves room for the characters to develop.  	1
# In a most wonderful location lies a story of contrast.  	1
# All in all a beautiful directed film from Nicola's roeg wih a sublime cast.  	1
# I'm translating movies for a living and this is the first movie in my 5-year working experience that I found offensive to my intelligence.  	0
# But when someone strives for greatness and poetry, but delivers a muddled (and often ridiculous) story, a bunch of disparate scenes, pretentious dialogue... Then you get the worst kind of a movie that some other reviewer very accurately defined as pretentious crap".   Prediction=> 1
# This place deserves no stars. Prediction=> 0
# It feels more comfortable than most headsets because I wear glasses and that gets in the way sometimes. Prediction=> 1
# The item received was Counterfeit. Prediction=> 0
# Works great!. Prediction=> 1
# It's so bad it's actually worth seeing just for that reason.   Prediction=> 0
# This scene is very strong and unpleasant.   Prediction=> 1
# good item, low price. Prediction=> 0
# very disappointed. Prediction=> 0
# All the characters in this film are tremendously well played.   Prediction=> 1
# Insults, profound deuchebaggery, and had to go outside for a smoke break while serving just to solidify it. Prediction=> 0
# Things that went wrong: - They burned the saganaki. Prediction=> 0
# I can barely ever hear on it and am constantly saying "what?" Prediction=> 0
# WORTHWHILE. Prediction=> 1
# And generally the lines and plot is weaker than the average episode.   Prediction=> 0
# The fish is badly made and some of its underwater shots are repeated a thousand times in the film.   Prediction=> 1
# Don't waste your money!. Prediction=> 0
# A good time! Prediction=> 1
# Performed awful -- muffled, tinny incoming sound and severe echo for those on the other end of the call. Prediction=> 0
# I believe that Pitch Black was done well.   Prediction=> 0
# Comfort for our whole family. Prediction=> 1
# Also its slim enough to fit into my alarm clock docking station without removing the case. Prediction=> 1
# I can say that the desserts were yummy. Prediction=> 1
# Star Trek V The final Frontier is the worst in the series.   Prediction=> 0
# The sets (especially designed to work with the camera) are amazing....stylized, beautiful and effective.   Prediction=> 1
# Everything was fresh and delicious! Prediction=> 1
# Join the club and get awesome offers via email. Prediction=> 1
# These were so good we ordered them twice. Prediction=> 1
# The acting is terrible, and the writing is worse.   Prediction=> 0
# So I basically threw my money out the window for nothing. Prediction=> 0
# The movie showed a lot of Florida at it's best, made it look very appealing.   Prediction=> 0
# Returned 8 hours later. Prediction=> 0
# The plantains were the worst I've ever tasted. Prediction=> 0
# Hopefully this bodes for them going out of business and someone who can cook can come in. Prediction=> 0
# Sauce was tasteless. Prediction=> 0
# I really recommend this faceplates since it looks very nice, elegant and cool. Prediction=> 1
# I'm a bit disappointed. Prediction=> 0
# A pretty good product. Prediction=> 1
# The Songs Were The Best And The Muppets Were So Hilarious.   Prediction=> 1
# Very convenient, since we were staying at the MGM! Prediction=> 0
# In fact, this stinker smells like a direct-to-video release.   Prediction=> 0
# The pairing of the two devices was so easy it barely took a couple minutes before I started making calls with the voice dialing feature. Prediction=> 0
# first time there and might just be the last. Prediction=> 0
# And it was boring.   Prediction=> 0
# At a time when it seems that film animation has been dominated by Disney/Pixar's CGI masterpieces, it is both refreshing and comforting to know that Miyazaki is still relying on traditional hand-drawn animation to tell his charming and enchanting stories.   Prediction=> 1
# If you haven't choked in your own vomit by the end (by all the cheap drama and worthless dialogue) you've must have bored yourself to death with this waste of time.   Prediction=> 0
# Worst food/service I've had in a while. Prediction=> 0
# The things that the four kids get themselves into is absolutely hilarious to watch.   Prediction=> 0
# The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity. Prediction=> 0
# What a piece of junk.. I lose more calls on this phone. Prediction=> 0
# Both films are terrible, but to the credit of the 1986 version, it was watchable.   Prediction=> 0
# Other than that, the leather is nice and soft; the fit is very tight; the cut out for the face is a good shape. Prediction=> 1
# The menu had so much good stuff on it i could not decide! Prediction=> 1
# I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great! Prediction=> 1
# I think it was Robert Ryans best film, because he portrayed someone like my father, and he was a schizophrenic in real life,(my father) although he never murdered anyone but was affected more so during the second world war which made him worse.   Prediction=> 0
# The film looks cheap and bland.   Prediction=> 0
# Very satisifed with that. Prediction=> 0
# High-quality chicken on the chicken Caesar salad. Prediction=> 0
# If you stay in Vegas you must get breakfast here at least once. Prediction=> 1
# This is one of the best movies out there that shows such strong sibling bond for each other.   Prediction=> 1
# I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine. Prediction=> 1
# At least 40min passed in between us ordering and the food arriving, and it wasn't that busy. Prediction=> 0
# Tasted like dirt. Prediction=> 0
# Linked to my phone without effort. Prediction=> 1
# A cheap and cheerless heist movie with poor characterisation, lots of underbite style stoic emoting (think Chow Yun Fat in A Better Tomorrow) and some cheesy clichés thrown into an abandoned factory ready for a few poorly executed flying judo rolls a la John Woo.   Prediction=> 0
# Also the area where my unit broke).- I'm not too fond of the magnetic strap. Prediction=> 0
# Poor quality. Prediction=> 0
# It definitely was not as good as my S11. Prediction=> 1
# However, my recent experience at this particular location was not so good. Prediction=> 0
# I would recommend saving room for this! Prediction=> 0
# There's really nothing bad I can say about this headset. Prediction=> 0
# Kind of flops around. Prediction=> 0
# It was that year, however, that reminded us that Huston was still at the top of his game as evinced by his faithful adaptation of James Joyce's acclaimed novella "The Dead.   Prediction=> 1
# THAT one didn't work either. Prediction=> 1
# Each track commands sentiment, actually contributing to the scenes and characters.   Prediction=> 1
# I have watched their prices inflate, portions get smaller and management attitudes grow rapidly! Prediction=> 1
# Jimmy Stewart is as ever a great hero for Hitchcock, the story rips along to its cool climax at an embassy function, but it lacks the brooding menace of Hitchcock's black and white, low-budget original.   Prediction=> 1
# The one big drawback of the MP3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds. Prediction=> 0
# The pancake was also really good and pretty large at that. Prediction=> 1
# Food was really good and I got full petty fast. Prediction=> 1
# - the food is rich so order accordingly. Prediction=> 1
# I'd love to go back. Prediction=> 1
# This was utterly confusing at first, which caused me to lose a couple of very, very important contacts. Prediction=> 0
# It is so small and you don't even realize that it is there after a while of getting used to it. Prediction=> 1
# say bye bye to your tip lady! Prediction=> 1
# Echo Problem....Very unsatisfactory Prediction=> 0
# Does not fit. Prediction=> 0
# But it picked up speed and got right to the point.   Prediction=> 1
# I bought two of them and neither will charge. Prediction=> 0
# IT'S REALLY EASY. Prediction=> 1
# Integrated seamlessly with the Motorola RAZR phone. Prediction=> 1
# Highly unrecommended.   Prediction=> 1
# This place is great!!!!!!!!!!!!!! Prediction=> 1
# Battery charge-life is quite long. Prediction=> 0
# Timely shipment and quality product. Prediction=> 1
# Will order from them again! Prediction=> 1
# Also difficult to put on.I'd recommend avoiding this product. Prediction=> 0
# The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues. Prediction=> 1
# ) some great music, and terrific scenery.   Prediction=> 1
# $50 Down the drain. Prediction=> 0
# Really good product. Prediction=> 1
# I love this bluetooth! Prediction=> 1
# Same evening, him and I are both drastically sick. Prediction=> 0
# This phone is pretty sturdy and I've never had any large problems with it. Prediction=> 1
# Director Paul Matthews, who also wrote/directed the weak 1995 monster movie "Grim", clearly doesn't know how to pace his films.   Prediction=> 0
# However, there was so much garlic in the fondue, it was barely edible. Prediction=> 0
# Freezes frequently4. Prediction=> 0
# We definately enjoyed ourselves. Prediction=> 1
# There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company. Prediction=> 0
# A world better than 95% of the garbage in the theatres today.   Prediction=> 0
# Definitely worth checking out.   Prediction=> 1
# This is a great deal. Prediction=> 1
# Food is way overpriced and portions are fucking small. Prediction=> 0
# Paying $7.85 for a hot dog and fries that looks like it came out of a kid's meal at the Wienerschnitzel is not my idea of a good meal. Prediction=> 1
# The lines, the cuts, the audio, everything is wrong.   Prediction=> 0
# I have always used corded headsets and the freedom from the wireless is very helpful. Prediction=> 0
# I found this move beautiful, enjoyable, and uplifting.   Prediction=> 1
# It never condescends, all the characters have good genuine hearts and believable problems.   Prediction=> 1
# Even if you love bad movies, do not watch this movie.   Prediction=> 1
# But she is still a bad actress, repeating her robotic face moves in each of her pictures.   Prediction=> 0
# Crust is not good. Prediction=> 1
# I have yet to run this new battery below two bars and that's three days without charging. Prediction=> 0
# This show is made for Americans - it is too stupid and full with hatred and clichés to be admitted elsewhere.   Prediction=> 0
# The movie has almost no action scenes in it and very little comedy.   Prediction=> 0
# I know he was a contract player with little control over his scripts, but the acting was as bad as the script.   Prediction=> 0
# Not a single employee came out to see if we were OK or even needed a water refill once they finally served us our food. Prediction=> 0
# I left the theater with a lilt in my step, joy in my heart and hope for the human race.   Prediction=> 0
# When Achille and Philippa beautifully sing a duet from "Don Giovanni" that perfectly describes their situation in the movie, you appreciate the subtle layers of this excellent film.   Prediction=> 1
# A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!! Prediction=> 0
# The majority of the Logitech earbud headsets failed. Prediction=> 0
# However-the riingtones are not the best, and neither are the games. Prediction=> 0
# First of all, it doesn't wear well. Prediction=> 1
# Earbud piece breaks easily. Prediction=> 0
# Nice quality build, unlike some cheap s*** out there. Prediction=> 1
# This movie is also revealing.   Prediction=> 1
# Always a great time at Dos Gringos! Prediction=> 1
# I don't each much pasta, but I love the homemade /hand made pastas and thin pizzas here. Prediction=> 1
# great...no problems at all!. Prediction=> 1
# The last 3 times I had lunch here has been bad. Prediction=> 0
# For a self proclaimed coffee cafe, I was wildly disappointed. Prediction=> 0
# Also, if your phone is dropped, this case is not going to save it, specially when dropped face down. Prediction=> 0
# This place was such a nice surprise! Prediction=> 1
# He was terrible! Prediction=> 0
# The chicken dishes are OK, the beef is like shoe leather. Prediction=> 1
# The script iswas there a script?   Prediction=> 0
# The directing is sloppy at best.   Prediction=> 0
# Works good. Prediction=> 1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print("Accuracy: ",pipe_tfid.score(X_test,y_test))
print("Accuracy: ",pipe_tfid.score(X_test,sample_prediction1))
# Out:
# Accuracy:  0.8069216757741348
# Accuracy:  1.0

# %%
# Accuracy on train set
print("Accuracy: ",pipe_tfid.score(X_train,y_train))
# Out:
# Accuracy:  0.9735883424408015
