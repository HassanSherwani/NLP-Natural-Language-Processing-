# %% [markdown]
# # Machine Translation

# %% [markdown]
# # 1)- Importing key modules

# %%
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# What's life without style :). So, let's add style to our dataframes
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
import string 
from string import digits
from collections import Counter
import re 
import numpy as np
from sklearn.utils import shuffle
import pandas as pd 
from pickle import dump
from pickle import load
from unicodedata import normalize
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import string 
import re 
from numpy import array, argmax, random, take 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
pd.set_option('display.max_colwidth', 200)

# %%
from keras.models import Sequential 
from keras.layers import Dense, LSTM, Embedding, RepeatVector
from keras.preprocessing.text import Tokenizer
from keras.callbacks import ModelCheckpoint 
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model 
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
# first install: pip install version_information
# %reload_ext version_information
# %version_information pandas,re,sklearn, matplotlib
# Out:
# Software versions
# Python 3.6.3 64bit [MSC v.1900 64 bit (AMD64)]
# IPython 7.4.0
# OS Windows 10 10.0.16299 SP0
# pandas 0.23.4
# re 2.2.1
# sklearn 0.20.3
# matplotlib 2.1.0
# Thu Sep 12 18:29:04 2019 W. Europe Daylight Time

# %% [markdown]
# # 2)- Loading data
#
# We have data from 2009 to 2016.

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
# split a loaded document into sentences
def to_sentences(doc):
	return doc.strip().split('\n')

# %%
# shortest and longest sentence lengths
def sentence_lengths(sentences):
	lengths = [len(s.split()) for s in sentences]
	return min(lengths), max(lengths)

# %% [markdown]
# ### 2.1)- For year 2009

# %%
# load English data
filename = 'newstest2009.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2009.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=2525, min=1, max=108
# German data: sentences=2525, min=1, max=110

# %% [markdown]
# It is important to notice that sentence length is same. So, we have a balanced data.
#
# We shall check this on all years

# %% [markdown]
# ### 2.2)-For 2010

# %%
# load English data
filename = 'newstest2010.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2010.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=2489, min=1, max=74
# German data: sentences=2489, min=1, max=86

# %% [markdown]
# ### 2.3)-For year 2011

# %%
# load English data
filename = 'newstest2011.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2011.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=3003, min=1, max=93
# German data: sentences=3003, min=1, max=92

# %% [markdown]
# ### 2.4)-For year 2012

# %%
# load English data
filename = 'newstest2012.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2012.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=3003, min=1, max=114
# German data: sentences=3003, min=1, max=101

# %% [markdown]
# ### 2.5)-For year 2013

# %%
# load English data
filename = 'newstest2013.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2013.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=3000, min=1, max=82
# German data: sentences=3000, min=1, max=85

# %% [markdown]
# ### 2.6)-For year 2014

# %%
# load English data
filename = 'newstest2014.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2014.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=3003, min=1, max=68
# German data: sentences=3003, min=1, max=64

# %% [markdown]
# ### 2.7)- For year 2015

# %%
# load English data
filename = 'newstest2015.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2015.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=2169, min=1, max=71
# German data: sentences=2169, min=1, max=72

# %% [markdown]
# ### For year 2016

# %%
# load English data
filename = 'newstest2016.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))

# load German data
filename = 'newstest2016.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('German data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=2999, min=1, max=83
# German data: sentences=2999, min=1, max=88

# %% [markdown]
# **All datasets have balanced sentences for English and German version**

# %% [markdown]
# # 3)- Data Cleaning
#
# - Tokenizing text by white space.
# - Normalizing case to lowercase.
# - Removing punctuation from each word.
# - Removing non-printable characters.
# - Removing words that contain non-alphabetic characters.
#
#
# **We shall use only one file(2015) for quick processing.**

# %%
# create cleaning function

def clean_lines(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for line in lines:
		# normalize unicode characters
		line = normalize('NFD', line).encode('ascii', 'ignore')
		line = line.decode('UTF-8')
		# tokenize on white space
		line = line.split()
		# convert to lower case
		line = [word.lower() for word in line]
		# remove punctuation from each token
		line = [word.translate(table) for word in line]
		# remove non-printable chars form each token
		line = [re_print.sub('', w) for w in line]
		# remove tokens with numbers in them
		line = [word for word in line if word.isalpha()]
		# store as string
		cleaned.append(' '.join(line))
	return cleaned

# %%
# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# %%
# load English data
filename = 'newstest2015.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2015.pkl')
# Out:
# Saved: english2015.pkl

# %%
# spot check for english version
for i in range(10):
	print(sentences[i])
# Out:
# india and japan prime ministers meet in tokyo
# indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election
# mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world
# high on the agenda are plans for greater nuclear cooperation
# india is also reportedly hoping for a deal on defence collaboration between the two nations
# karratha police arrest after high speed motorcycle chase
# a motorcycle has been seized after it was ridden at in a zone and through bushland to escape police in the pilbara
# traffic police on patrol in karratha this morning tried to pull over a blue motorcycle when they spotted it reaching as it pulled out of a service station on bathgate road
# police say the rider then failed to stop and continued on to burgess road before turning into bushland causing the officers to lose sight of it
# the motorcycle and a person matching the description of the rider was then spotted at a house on walcott way in bulgarra

# %%
# load and check German data

filename = 'newstest2015.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2015.pkl')
# spot check for german version
for i in range(10):
	print(sentences[i])
# Out:
# Saved: german2015.pkl
# die premierminister indiens und japans trafen sich in tokio
# indiens neuer premierminister narendra modi trifft bei seinem ersten wichtigen auslandsbesuch seit seinem wahlsieg im mai seinen japanischen amtskollegen shinzo abe in toko um wirtschaftliche und sicherheitspolitische beziehungen zu besprechen
# herr modi befindet sich auf einer funftagigen reise nach japan um die wirtschaftlichen beziehungen mit der drittgroten wirtschaftsnation der welt zu festigen
# plane fur eine starkere kerntechnische zusammenarbeit stehen ganz oben auf der tagesordnung
# berichten zufolge hofft indien daruber hinaus auf einen vertrag zur verteidigungszusammenarbeit zwischen den beiden nationen
# polizei von karratha verhaftet nach schneller motorradjagd
# ein motorrad wurde beschlagnahmt nachdem der fahrer es mit kmh in einer kmhzone und durch buschland gefahren hatte um der polizei in bilbara zu entkommen
# verkehrspolizisten in karratha versuchten heute morgen ein blaues motorrad zu stoppen nachdem sie es dabei beobachtet hatten wie es mit kmh eine tankstelle auf der bathdate road verlie
# die polizei berichtet dass der fahrer die haltesignale dann ignorierte und weiter auf der burgess road fuhr bevor er in das buschland abbog wo die beamten es aus den augen verloren
# das motorrad sowie eine person die der beschreibung des fahrers entsprach wurden spater bei einem haus im walcott way in bulgarra gesehen

# %% [markdown]
# # 4)- Vocab frequency

# %%
# function to load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# %%
def to_vocab(lines):
	vocab = Counter()
	for line in lines:
		tokens = line.split()
		vocab.update(tokens)
	return vocab

# %% [markdown]
# ### 4a)-original file

# %%
# load English dataset i.e pickled earlier
filename = 'english2015.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 7227

# %%
# load German dataset i.e pickled earlier
filename = 'german2015.pkl'
lines = load_clean_sentences(filename)
# calculate vocabulary
vocab = to_vocab(lines)
print('German Vocabulary: %d' % len(vocab))
# Out:
# German Vocabulary: 9280

# %% [markdown]
# # 5)-For pickle files

# %%
df_clean_eng= pd.read_pickle('english2015.pkl')

# %%
type(df_clean_eng)
# Out:
# list

# %%
df_clean_eng[:5]
# Out:
# ['india and japan prime ministers meet in tokyo',
#  'indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election',
#  'mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world',
#  'high on the agenda are plans for greater nuclear cooperation',
#  'india is also reportedly hoping for a deal on defence collaboration between the two nations']

# %%
new_eng=pd.DataFrame(df_clean_eng, columns=['eng'])

# %%
new_eng.head()
# Out:
#                                                                                                                                                                                                   eng
# 0                                                                                                                                                       india and japan prime ministers meet in tokyo
# 1  indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election
# 2                                                                                       mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world
# 3                                                                                                                                        high on the agenda are plans for greater nuclear cooperation
# 4                                                                                                         india is also reportedly hoping for a deal on defence collaboration between the two nations

# %%
new_eng.shape
# Out:
# (2169, 1)

# %% [markdown]
# **save as of text file**

# %%
new_eng.to_csv(r'english2015.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ### 5b)- for german

# %%
df_clean_ger= pd.read_pickle('german2015.pkl')

# %%
type(df_clean_ger)
# Out:
# list

# %%
new_ger=pd.DataFrame(df_clean_ger, columns=['ger'])

# %%
new_ger.head()
# Out:
#                                                                                                                                                                                                        ger
# 0                                                                                                                                              die premierminister indiens und japans trafen sich in tokio
# 1  indiens neuer premierminister narendra modi trifft bei seinem ersten wichtigen auslandsbesuch seit seinem wahlsieg im mai seinen japanischen amtskollegen shinzo abe in toko um wirtschaftliche und ...
# 2                                            herr modi befindet sich auf einer funftagigen reise nach japan um die wirtschaftlichen beziehungen mit der drittgroten wirtschaftsnation der welt zu festigen
# 3                                                                                                              plane fur eine starkere kerntechnische zusammenarbeit stehen ganz oben auf der tagesordnung
# 4                                                                             berichten zufolge hofft indien daruber hinaus auf einen vertrag zur verteidigungszusammenarbeit zwischen den beiden nationen

# %%
new_ger.shape
# Out:
# (2169, 1)

# %% [markdown]
# **save as text file**

# %%
new_ger.to_csv(r'german2015.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ### Combine files

# %%
df_combine_2015_clean=pd.concat([new_eng, new_ger], axis=1, join='inner') # to adjust automatically row labels i.e index
df_combine_2015_clean.shape
# Out:
# (2169, 2)

# %%
df_combine_2015_clean.head()
# Out:
#                                                                                                                                                                                                   eng  \
# 0                                                                                                                                                       india and japan prime ministers meet in tokyo
# 1  indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election
# 2                                                                                       mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world
# 3                                                                                                                                        high on the agenda are plans for greater nuclear cooperation
# 4                                                                                                         india is also reportedly hoping for a deal on defence collaboration between the two nations
#
#                                                                                                                                                                                                        ger
# 0                                                                                                                                              die premierminister indiens und japans trafen sich in tokio
# 1  indiens neuer premierminister narendra modi trifft bei seinem ersten wichtigen auslandsbesuch seit seinem wahlsieg im mai seinen japanischen amtskollegen shinzo abe in toko um wirtschaftliche und ...
# 2                                            herr modi befindet sich auf einer funftagigen reise nach japan um die wirtschaftlichen beziehungen mit der drittgroten wirtschaftsnation der welt zu festigen
# 3                                                                                                              plane fur eine starkere kerntechnische zusammenarbeit stehen ganz oben auf der tagesordnung
# 4                                                                             berichten zufolge hofft indien daruber hinaus auf einen vertrag zur verteidigungszusammenarbeit zwischen den beiden nationen

# %% [markdown]
# ### save work as pickle

# %%
df_combine_2015_clean.to_pickle('data_2015_clean_preprocess.pkl')

# %%
df_combine_2015_clean.to_csv('data_2015_clean.csv')

# %% [markdown]
# ### save as text file too

# %%
df_combine_2015_clean.to_csv(r'data_2015_clean.txt', header=None, index=None)

# %%
# or use np.......

np.savetxt(r'data_2015_clean_np.txt', df_combine_2015_clean.eng+df_combine_2015_clean.ger , fmt='%s')

# %% [markdown]
# # 6)- Combining all files from 2009-2016

# %% [markdown]
# ### 6a.All english versions

# %%
# load English data
filename = 'newstest2009.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2009.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2009.pkl
# prague stock market falls to minus by the end of the trading day
# after a sharp drop in the morning the prague stock market corrected its losses
# transactions with stocks from the czech energy enterprise cez reached nearly half of the regular daily trading
# the prague stock market immediately continued its fall from monday at the beginning of tuesdays trading when it dropped by nearly six percent
# this time the fall in stocks on wall street is responsible for the drop
# the reaction of the market to the results of the vote in the american house of representatives which refused to support the plan for the stabilization of the financial sector there has manifested itself here as well
# stocks fall in asia
# stocks in the asian markets experienced a dramatic drop on tuesday even though the indexes ultimately erased a part of the losses during the day
# the hang seng index of the hong kong stock exchange wrote off nearly four percent during the day but later it erased a part of the losses and reduced the decrease to roughly percent
# the hang seng china enterprises index which follows the movement of chinese stocks on the stock market in hong kong dropped by percent in shanghai the markets were closed

# %%
# load English dataset i.e pickled earlier
filename = 'english2009.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 8601

# %% [markdown]
# **create dataframe**

# %%
ls_2009= pd.read_pickle('english2009.pkl')

# %%
type(df_clean_eng)
# Out:
# list

# %%
df_2009=pd.DataFrame(ls_2009, columns=['eng'])

# %%
df_2009.head(2)
# Out:
#                                                                               eng
# 0                prague stock market falls to minus by the end of the trading day
# 1  after a sharp drop in the morning the prague stock market corrected its losses

# %%
df_2009.shape
# Out:
# (2525, 1)

# %% [markdown]
# **save as text for model 1**

# %%
df_2009.to_csv(r'eng_data_2009.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# #### for 2010

# %%
# load English data
filename = 'newstest2010.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2010.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2010.pkl
# barack obama becomes the fourth american president to receive the nobel peace prize
# the american president barack obama will fly into oslo norway for hours to receive the nobel peace prize the fourth american president in history to do so
# he will receive a diploma medal and cheque for million dollars for his exceptional efforts to improve global diplomacy and encourage international cooperation amongst other things
# the head of the white house will be flying into the norwegian city in the morning with his wife michelle and will have a busy schedule
# first he will visit the nobel institute where he will have his first meeting with the five committee members who selected him from people and organisations

# %%
# load English dataset i.e pickled earlier
filename = 'english2010.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 8526

# %%
ls_2010= pd.read_pickle('english2010.pkl')
type(ls_2010)
# Out:
# list

# %%
df_2010=pd.DataFrame(ls_2010, columns=['eng'])
df_2010.shape
# Out:
# (2489, 1)

# %%
df_2010.head(3)
# Out:
#                                                                                                                                                                                    eng
# 0                                                                                                  barack obama becomes the fourth american president to receive the nobel peace prize
# 1                           the american president barack obama will fly into oslo norway for hours to receive the nobel peace prize the fourth american president in history to do so
# 2  he will receive a diploma medal and cheque for million dollars for his exceptional efforts to improve global diplomacy and encourage international cooperation amongst other things

# %% [markdown]
# #### 2011

# %%
# load English data
filename = 'newstest2011.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2011.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2011.pkl
# what will they do cssd lacks knowledge of both voldemort and candy bars in prague
# new councilors of cssd will most probably have to overcome certain language barriers to understand their oldnew colleagues from ods in prague council and municipal council
# aktualnecz tested the social democrat members of the new council in terms of the wellestablished slang that originated in the town hall during the few last years when prague was ruled by the current coalition partners
# coded vocabulary that was established by prague political elite during the previous era of the mayor pavel bem describes some of the most famous persons situations and affairs in the city
# surprisingly it turned out that the new council members do not understand the wellknown concepts

# %%
# load English dataset i.e pickled earlier
filename = 'english2011.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 9868

# %%
ls_2011= pd.read_pickle('english2011.pkl')
type(ls_2011)
# Out:
# list

# %%
df_2011=pd.DataFrame(ls_2011, columns=['eng'])
df_2011.shape
# Out:
# (3003, 1)

# %%
df_2011.head(3)
# Out:
#                                                                                                                                                                                                        eng
# 0                                                                                                                        what will they do cssd lacks knowledge of both voldemort and candy bars in prague
# 1                              new councilors of cssd will most probably have to overcome certain language barriers to understand their oldnew colleagues from ods in prague council and municipal council
# 2  aktualnecz tested the social democrat members of the new council in terms of the wellestablished slang that originated in the town hall during the few last years when prague was ruled by the curre...

# %% [markdown]
# #### for 2012

# %%
# load English data
filename = 'newstest2012.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2012.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2012.pkl
# parliament does not support amendment freeing tymoshenko
# today the ukraine parliament dismissed within the code of criminal procedure amendment the motion to revoke an article based on which the opposition leader yulia tymoshenko was sentenced
# the amendment that would lead to freeing the imprisoned former prime minister was revoked during second reading of the proposal for mitigation of sentences for economic offences
# in october tymoshenko was sentenced to seven years in prison for entering into what was reported to be a disadvantageous gas deal with russia
# the verdict is not yet final the court will hear tymoshenkos appeal in december

# %%
# load English dataset i.e pickled earlier
filename = 'english2012.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 9138

# %%
ls_2012= pd.read_pickle('english2012.pkl')
type(ls_2012)
# Out:
# list

# %%
df_2012=pd.DataFrame(ls_2012, columns=['eng'])
df_2012.shape
# Out:
# (3003, 1)

# %%
df_2012.head(3)
# Out:
#                                                                                                                                                                                           eng
# 0                                                                                                                                    parliament does not support amendment freeing tymoshenko
# 1  today the ukraine parliament dismissed within the code of criminal procedure amendment the motion to revoke an article based on which the opposition leader yulia tymoshenko was sentenced
# 2           the amendment that would lead to freeing the imprisoned former prime minister was revoked during second reading of the proposal for mitigation of sentences for economic offences

# %% [markdown]
# #### for 2013

# %%
# load English data
filename = 'newstest2013.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2013.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2013.pkl
# a republican strategy to counter the reelection of obama
# republican leaders justified their policy by the need to combat electoral fraud
# however the brennan centre considers this a myth stating that electoral fraud is rarer in the united states than the number of people killed by lightning
# indeed republican lawyers identified only cases of electoral fraud in the united states in a decade
# one thing is certain these new provisions will have a negative impact on voter turnout

# %%
# load English dataset i.e pickled earlier
filename = 'english2013.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 8629

# %%
ls_2013= pd.read_pickle('english2013.pkl')
type(ls_2013)
# Out:
# list

# %%
df_2013=pd.DataFrame(ls_2013, columns=['eng'])
df_2013.shape
# Out:
# (3000, 1)

# %%
df_2013.head(3)
# Out:
#                                                                                                                                                          eng
# 0                                                                                                   a republican strategy to counter the reelection of obama
# 1                                                                            republican leaders justified their policy by the need to combat electoral fraud
# 2  however the brennan centre considers this a myth stating that electoral fraud is rarer in the united states than the number of people killed by lightning

# %% [markdown]
# #### for 2014

# %%
# load English data
filename = 'newstest2014.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2014.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2014.pkl
# gutach increased safety for pedestrians
# they are not even metres apart on tuesday the new b pedestrian lights in dorfparkplatz in gutach became operational within view of the existing town hall traffic lights
# two sets of lights so close to one another intentional or just a silly error
# yesterday gutachts mayor gave a clear answer to this question
# at the time the town hall traffic lights were installed because this was a school route explained eckert yesterday

# %%
# load English dataset i.e pickled earlier
filename = 'english2014.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 9290

# %%
ls_2014= pd.read_pickle('english2014.pkl')
type(ls_2014)
# Out:
# list

# %%
df_2014=pd.DataFrame(ls_2014, columns=['eng'])
df_2014.shape
# Out:
# (3003, 1)

# %%
df_2014.head(3)
# Out:
#                                                                                                                                                                         eng
# 0                                                                                                                                   gutach increased safety for pedestrians
# 1  they are not even metres apart on tuesday the new b pedestrian lights in dorfparkplatz in gutach became operational within view of the existing town hall traffic lights
# 2                                                                                              two sets of lights so close to one another intentional or just a silly error

# %% [markdown]
# #### 2015

# %%
# load English data
filename = 'newstest2015.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2015.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2015.pkl
# india and japan prime ministers meet in tokyo
# indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election
# mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world
# high on the agenda are plans for greater nuclear cooperation
# india is also reportedly hoping for a deal on defence collaboration between the two nations

# %%
# load English dataset i.e pickled earlier
filename = 'english2015.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 7227

# %%
ls_2015= pd.read_pickle('english2015.pkl')
type(ls_2015)
# Out:
# list

# %%
df_2015=pd.DataFrame(ls_2015, columns=['eng'])
df_2015.shape
# Out:
# (2169, 1)

# %%
df_2015.head(3)
# Out:
#                                                                                                                                                                                                   eng
# 0                                                                                                                                                       india and japan prime ministers meet in tokyo
# 1  indias new prime minister narendra modi is meeting his japanese counterpart shinzo abe in tokyo to discuss economic and security ties on his first major foreign visit since winning mays election
# 2                                                                                       mr modi is on a fiveday trip to japan to strengthen economic ties with the third largest economy in the world

# %% [markdown]
# #### 2016

# %%
# load English data
filename = 'newstest2016.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'english2016.pkl')

#spot check for english version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: english2016.pkl
# obama receives netanyahu
# the relationship between obama and netanyahu is not exactly friendly
# the two wanted to talk about the implementation of the international agreement and about teherans destabilising activities in the middle east
# the meeting was also planned to cover the conflict with the palestinians and the disputed two state solution
# relations between obama and netanyahu have been strained for years

# %%
# load English dataset i.e pickled earlier
filename = 'english2016.pkl'
lines = load_clean_sentences(filename)

# calculate vocabulary
vocab = to_vocab(lines)
print('English Vocabulary: %d' % len(vocab))
# Out:
# English Vocabulary: 8696

# %%
ls_2016= pd.read_pickle('english2016.pkl')
type(ls_2016)
# Out:
# list

# %%
df_2016=pd.DataFrame(ls_2016, columns=['eng'])
df_2016.shape
# Out:
# (2999, 1)

# %%
df_2016.head(3)
# Out:
#                                                                                                                                              eng
# 0                                                                                                                       obama receives netanyahu
# 1                                                                           the relationship between obama and netanyahu is not exactly friendly
# 2  the two wanted to talk about the implementation of the international agreement and about teherans destabilising activities in the middle east

# %% [markdown]
# **combine all english datasets from 2009-2016**

# %%
df_eng_all=pd.concat([df_2009,df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016], ignore_index=True)

# %%
print("shape of combined Cleaned English version is", df_eng_all.shape)
# Out:
# shape of combined Cleaned English version is (22191, 1)

# %% [markdown]
# **save as text file**

# %%
df_eng_all.to_csv(r'english_all.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ### 6b.all german version

# %%
# load and check German data

filename = 'newstest2009.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2009.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2009.pkl
# die prager borse sturzt gegen geschaftsschluss ins minus
# nach dem steilen abfall am morgen konnte die prager borse die verluste korrigieren
# die transaktionen mit den aktien von cez erreichten fast die halfte des normalen tagesgeschafts
# die prager borse knupfte gleich zu beginn der dienstagsgeschafte an den einbruch vom montag an als sie um weitere sechs prozentpunkte sank
# diesmal lag der grund fur den einbruch an der wall street

# %%
# load German dataset i.e pickled earlier
filename = 'german2009.pkl'
lines = load_clean_sentences(filename)
# calculate vocabulary
vocab = to_vocab(lines)
print('German Vocabulary: %d' % len(vocab))
# Out:
# German Vocabulary: 11770

# %%
ls_ger_2009= pd.read_pickle('german2009.pkl')
type(ls_ger_2009)
# Out:
# list

# %%
df_ger_2009=pd.DataFrame(ls_ger_2009, columns=['ger'])
df_ger_2009.shape
# Out:
# (2525, 1)

# %%
df_ger_2009.head(3)
# Out:
#                                                                                                ger
# 0                                         die prager borse sturzt gegen geschaftsschluss ins minus
# 1               nach dem steilen abfall am morgen konnte die prager borse die verluste korrigieren
# 2  die transaktionen mit den aktien von cez erreichten fast die halfte des normalen tagesgeschafts

# %% [markdown]
# **save as text file for model 1**

# %%
df_ger_2009.to_csv(r'ger_data_2009.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# #### 2010

# %%
# load and check German data

filename = 'newstest2010.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2010.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2010.pkl
# barack obama erhalt als vierter usprasident den friedensnobelpreis
# der amerikanische prasident barack obama kommt fur stunden nach oslo norwegen um hier als vierter usprasident in der geschichte den friedensnobelpreis entgegenzunehmen
# daruber hinaus erhalt er das diplom sowie die medaille und einen scheck uber mio dollar fur seine auergewohnlichen bestrebungen um die intensivierung der weltdiplomatie und zusammenarbeit unter den volkern
# der chef des weien hauses kommt morgen zusammen mit seiner frau michelle in der nordwegischen metropole an und wird die ganze zeit beschaftigt sein
# zunachst stattet er dem nobelinstitut einen besuch ab wo er uberhaupt zum erstenmal mit den funf ausschussmitglieder zusammentrifft die ihn im oktober aus leuten und organisationen gewahlt haben

# %%
ls_ger_2010= pd.read_pickle('german2010.pkl')
type(ls_ger_2010)
# Out:
# list

# %%
df_ger_2010=pd.DataFrame(ls_ger_2010, columns=['ger'])
df_ger_2010.shape
# Out:
# (2489, 1)

# %%
df_ger_2010.head(3)
# Out:
#                                                                                                                                                                                                        ger
# 0                                                                                                                                       barack obama erhalt als vierter usprasident den friedensnobelpreis
# 1                                  der amerikanische prasident barack obama kommt fur stunden nach oslo norwegen um hier als vierter usprasident in der geschichte den friedensnobelpreis entgegenzunehmen
# 2  daruber hinaus erhalt er das diplom sowie die medaille und einen scheck uber mio dollar fur seine auergewohnlichen bestrebungen um die intensivierung der weltdiplomatie und zusammenarbeit unter de...

# %% [markdown]
# #### 2011

# %%
# load and check German data

filename = 'newstest2011.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2011.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2011.pkl
# was soll sie tun die cssd die tschechischen sozialdemokraten in prag kennen weder voldemort noch die konditorei
# die neuen ratsherren der hauptstadt aus den reihen der cssd werden offensichtlich gewisse sprachbarrieren uberwinden mussen um ihre altneuen kollegen aus der ods im prager rat und in der stadtvertretung uberhaupt verstehen zu konnen
# die zeitung aktualnecz hat mitglieder des neuen rates aus der cssd mal ein wenig abgeklopft wie sie den notorischen slang beherrschen der sich in den letzten jahren eingeburgert hat in denen die heutigen koalitionspartner in prag am ruder waren
# der codierte wortschatz der in der verflossenen ara von oberburgermeister pavel bem von der prager politischen elite eingefuhrt wurde ist einigen der bekanntesten akteure situationen und causae entlehnt
# uberraschenderweise zeigte sich dass die neuen rate in bezug auf die diese neuen begriffe etwas im dunkeln tappen

# %%
ls_ger_2011= pd.read_pickle('german2011.pkl')
type(ls_ger_2011)
# Out:
# list

# %%
df_ger_2011=pd.DataFrame(ls_ger_2011, columns=['ger'])
df_ger_2011.shape
# Out:
# (3003, 1)

# %%
df_ger_2011.head(3)
# Out:
#                                                                                                                                                                                                        ger
# 0                                                                                          was soll sie tun die cssd die tschechischen sozialdemokraten in prag kennen weder voldemort noch die konditorei
# 1  die neuen ratsherren der hauptstadt aus den reihen der cssd werden offensichtlich gewisse sprachbarrieren uberwinden mussen um ihre altneuen kollegen aus der ods im prager rat und in der stadtvert...
# 2  die zeitung aktualnecz hat mitglieder des neuen rates aus der cssd mal ein wenig abgeklopft wie sie den notorischen slang beherrschen der sich in den letzten jahren eingeburgert hat in denen die h...

# %% [markdown]
# #### 2012

# %%
# load and check German data

filename = 'newstest2012.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2012.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2012.pkl
# keine befreiende novelle fur tymoshenko durch das parlament
# das ukrainische parlament verweigerte heute den antrag im rahmen einer novelle des strafgesetzbuches denjenigen paragrafen abzuschaffen auf dessen grundlage die oppositionsfuhrerin yulia timoshenko verurteilt worden war
# die neuregelung die den weg zur befreiung der inhaftierten expremierministerin hatte ebnen konnen lehnten die abgeordneten bei der zweiten lesung des antrags auf milderung der strafen fur wirtschaftliche delikte ab
# timoshenko war im oktober wegen des abschlusses eines angeblich nachteiligen vertrags mit russland uber den einkauf von erdgas zu sieben jahren haft verurteilt worden
# das urteil ist noch nicht rechtskraftig im dezember soll die berufung der verurteilten vor gericht verhandelt werden

# %%
ls_ger_2012= pd.read_pickle('german2012.pkl')
type(ls_ger_2012)
# Out:
# list

# %%
df_ger_2012=pd.DataFrame(ls_ger_2012, columns=['ger'])
df_ger_2012.shape
# Out:
# (3003, 1)

# %%
df_ger_2012.head(3)
# Out:
#                                                                                                                                                                                                        ger
# 0                                                                                                                                              keine befreiende novelle fur tymoshenko durch das parlament
# 1  das ukrainische parlament verweigerte heute den antrag im rahmen einer novelle des strafgesetzbuches denjenigen paragrafen abzuschaffen auf dessen grundlage die oppositionsfuhrerin yulia timoshenk...
# 2  die neuregelung die den weg zur befreiung der inhaftierten expremierministerin hatte ebnen konnen lehnten die abgeordneten bei der zweiten lesung des antrags auf milderung der strafen fur wirtscha...

# %% [markdown]
# #### 2013

# %%
filename = 'newstest2013.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2013.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2013.pkl
# eine republikanische strategie um der wiederwahl von obama entgegenzutreten
# die fuhrungskrafte der republikaner rechtfertigen ihre politik mit der notwendigkeit den wahlbetrug zu bekampfen
# allerdings halt das brennan center letzteres fur einen mythos indem es bekraftigt dass der wahlbetrug in den usa seltener ist als die anzahl der vom blitzschlag getoteten menschen
# die rechtsanwalte der republikaner haben in jahren in den usa ubrigens nur falle von wahlbetrug verzeichnet
# eins ist sicher diese neuen bestimmungen werden sich negativ auf die wahlbeteiligung auswirken

# %%
ls_ger_2013= pd.read_pickle('german2013.pkl')
type(ls_ger_2013)
# Out:
# list

# %%
df_ger_2013=pd.DataFrame(ls_ger_2013, columns=['ger'])
df_ger_2013.shape
# Out:
# (3000, 1)

# %%
df_ger_2013.head(3)
# Out:
#                                                                                                                                                                                    ger
# 0                                                                                                          eine republikanische strategie um der wiederwahl von obama entgegenzutreten
# 1                                                                     die fuhrungskrafte der republikaner rechtfertigen ihre politik mit der notwendigkeit den wahlbetrug zu bekampfen
# 2  allerdings halt das brennan center letzteres fur einen mythos indem es bekraftigt dass der wahlbetrug in den usa seltener ist als die anzahl der vom blitzschlag getoteten menschen

# %% [markdown]
# #### 2014

# %%
filename = 'newstest2014.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2014.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2014.pkl
# gutach noch mehr sicherheit fur fuganger
# sie stehen keine meter voneinander entfernt am dienstag ist in gutach die neue b am dorfparkplatz in betrieb genommen worden in sichtweite der alteren rathausampel
# zwei anlagen so nah beieinander absicht oder schildburgerstreich
# diese frage hat gutachs burgermeister gestern klar beantwortet
# die rathausampel ist damals installiert worden weil diese den schulweg sichert erlauterte eckert gestern

# %%
ls_ger_2014= pd.read_pickle('german2014.pkl')
type(ls_ger_2014)
# Out:
# list

# %%
df_ger_2014=pd.DataFrame(ls_ger_2014, columns=['ger'])
df_ger_2014.shape
# Out:
# (3003, 1)

# %%
df_ger_2014.head(3)
# Out:
#                                                                                                                                                                    ger
# 0                                                                                                                             gutach noch mehr sicherheit fur fuganger
# 1  sie stehen keine meter voneinander entfernt am dienstag ist in gutach die neue b am dorfparkplatz in betrieb genommen worden in sichtweite der alteren rathausampel
# 2                                                                                                     zwei anlagen so nah beieinander absicht oder schildburgerstreich

# %% [markdown]
# #### 2015

# %%
filename = 'newstest2015.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2015.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2015.pkl
# die premierminister indiens und japans trafen sich in tokio
# indiens neuer premierminister narendra modi trifft bei seinem ersten wichtigen auslandsbesuch seit seinem wahlsieg im mai seinen japanischen amtskollegen shinzo abe in toko um wirtschaftliche und sicherheitspolitische beziehungen zu besprechen
# herr modi befindet sich auf einer funftagigen reise nach japan um die wirtschaftlichen beziehungen mit der drittgroten wirtschaftsnation der welt zu festigen
# plane fur eine starkere kerntechnische zusammenarbeit stehen ganz oben auf der tagesordnung
# berichten zufolge hofft indien daruber hinaus auf einen vertrag zur verteidigungszusammenarbeit zwischen den beiden nationen

# %%
ls_ger_2015= pd.read_pickle('german2015.pkl')
type(ls_ger_2015)
# Out:
# list

# %%
df_ger_2015=pd.DataFrame(ls_ger_2015, columns=['ger'])
df_ger_2015.shape
# Out:
# (2169, 1)

# %%
df_ger_2015.head(3)
# Out:
#                                                                                                                                                                                                        ger
# 0                                                                                                                                              die premierminister indiens und japans trafen sich in tokio
# 1  indiens neuer premierminister narendra modi trifft bei seinem ersten wichtigen auslandsbesuch seit seinem wahlsieg im mai seinen japanischen amtskollegen shinzo abe in toko um wirtschaftliche und ...
# 2                                            herr modi befindet sich auf einer funftagigen reise nach japan um die wirtschaftlichen beziehungen mit der drittgroten wirtschaftsnation der welt zu festigen

# %% [markdown]
# #### 2016

# %%
filename = 'newstest2016.de'
doc = load_doc(filename)
sentences = to_sentences(doc)
sentences = clean_lines(sentences)
save_clean_sentences(sentences, 'german2016.pkl')
# spot check for german version
for i in range(5):
	print(sentences[i])
# Out:
# Saved: german2016.pkl
# obama empfangt netanyahu
# das verhaltnis zwischen obama und netanyahu ist nicht gerade freundschaftlich
# die beiden wollten uber die umsetzung der internationalen vereinbarung sowie uber teherans destabilisierende manahmen im nahen osten sprechen
# bei der begegnung soll es aber auch um den konflikt mit den palastinensern und die diskutierte zweistaatenlosung gehen
# das verhaltnis zwischen obama und netanyahu ist seit jahren gespannt

# %%
ls_ger_2016= pd.read_pickle('german2016.pkl')
type(ls_ger_2016)
# Out:
# list

# %%
df_ger_2016=pd.DataFrame(ls_ger_2016, columns=['ger'])
df_ger_2016.shape
# Out:
# (2999, 1)

# %%
df_ger_2016.head(3)
# Out:
#                                                                                                                                              ger
# 0                                                                                                                       obama empfangt netanyahu
# 1                                                                  das verhaltnis zwischen obama und netanyahu ist nicht gerade freundschaftlich
# 2  die beiden wollten uber die umsetzung der internationalen vereinbarung sowie uber teherans destabilisierende manahmen im nahen osten sprechen

# %% [markdown]
# **combine all german dataset**

# %%
df_ger_all=pd.concat([df_ger_2009,df_ger_2010,df_ger_2011,df_ger_2012,df_ger_2013,df_ger_2014,df_ger_2015,df_ger_2016], ignore_index=True)

# %%
df_ger_all.shape
# Out:
# (22191, 1)

# %% [markdown]
# **save as text file**

# %%
df_ger_all.to_csv(r'german_all.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ### 6c. combine english+german

# %%
df_combine=pd.concat([df_eng_all,df_ger_all], axis=1, join='inner') # to adjust automatically row labels i.e index
df_combine.head(5)
# Out:
#                                                                                                                                              eng  \
# 0                                                                               prague stock market falls to minus by the end of the trading day
# 1                                                                 after a sharp drop in the morning the prague stock market corrected its losses
# 2                                 transactions with stocks from the czech energy enterprise cez reached nearly half of the regular daily trading
# 3  the prague stock market immediately continued its fall from monday at the beginning of tuesdays trading when it dropped by nearly six percent
# 4                                                                        this time the fall in stocks on wall street is responsible for the drop
#
#                                                                                                                                           ger
# 0                                                                                    die prager borse sturzt gegen geschaftsschluss ins minus
# 1                                                          nach dem steilen abfall am morgen konnte die prager borse die verluste korrigieren
# 2                                             die transaktionen mit den aktien von cez erreichten fast die halfte des normalen tagesgeschafts
# 3  die prager borse knupfte gleich zu beginn der dienstagsgeschafte an den einbruch vom montag an als sie um weitere sechs prozentpunkte sank
# 4                                                                                   diesmal lag der grund fur den einbruch an der wall street

# %%
df_combine.shape
# Out:
# (22191, 2)

# %% [markdown]
# **save as text**

# %%
df_combine.to_csv(r'full_data_clean.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# **save as pickle**

# %%
df_combine.to_pickle('full_data_clean.pkl')

# %% [markdown]
# ### 6d. test data for model
#
# Make them random

# %%
df_test=df_combine.sample(5000)

# %%
df_test.shape
# Out:
# (5000, 2)

# %% [markdown]
# **check if it works**

# %%
df_test.eng[18]
# Out:
# 'on monday the american house of representatives rejected the plan to support the financial system into which up to billion dollars nearly billion czech crowns was to be invested'

# %%
df_test.ger[18]
# Out:
# 'das amerikanische reprasentantenhaus hat am montag den plan fur eine unterstutzung des finanzsystems abgelehnt fur das bis zu milliarden dollar fast billionen kc aufgewendet werden sollten'

# %%
df_test.tail(10)
# Out:
#                                                                                                                                                                                                            eng  \
# 14633  this law is draconian and very punitive and we reject it said cyrus kamau managing director for capital group home to capitalfm one of kenyas most respected independent radio stations and news web...
# 1510                                                                                                     the rhythm was not very steady during the match and the attackers found it hard to express themselves
# 4576                                                                                                                                                          the feel of the steering wheel is also exquisite
# 8355                                                                                         it holds the most patents of all american technology companies five of its employees were awarded the nobel price
# 9996                                                             he is expected to present a cabinet composed largely of technocrats although it is unclear when the new executive will undertake the position
# 344                                                                                                          the campaign will appear on television on the radio in cinemas on the internet but also on flyers
# 18991                                                                                                                                    for one of whom captain hofmann the break came in particularly useful
# 10418                   in the scene peters a well known canadian comedian of indian origin who recently appeared as a presenter on the tour of my violent torpedo of truth by charlie sheen appears as joseph
# 18828                                                                                                                          in his opinion all members of each club could come together again in the future
# 1899                                               according to our information kubatov admitted having issued bills to atlasz hoppa and egyutt a harmadik evezredert alapitvany and received the amounts paid
#
#                                                                                                                                                                                                            ger
# 14633  das gesetz ist drakonisch und sehr strafend und wir lehnen es ab sagte cyrus kamau geschaftsfuhrer der capital group zu der auch capitalfm gehort eine der angesehensten unabhangigen radiostationen...
# 1510                                                                                                     das tempo dieser begegnung bei der die angreifer muhe hatten ihr konnen zu zeigen war nicht sehr hoch
# 4576                                                                                                                                                           ferner ist das spiel des lenkrads ausgezeichnet
# 8355                                                 von allen amerikanischen technologieunternehmen besitzt ibm die meisten patente und schon funf seiner mitarbeiter wurden mit dem nobelpreis ausgezeichnet
# 9996          es wird davon ausgegangen dass er ein mehrheitlich aus technokraten zusammengesetztes kabinett vorstellen wird obwohl noch nicht klar ist wann der neue ministerprasident sein amt antreten wird
# 344                                                                                               die kampagne fur millionen kronen wird im fernsehen im radio im kino im internet aber auch auf flyern laufen
# 18991                                                                                                                                     einer dem die pause wohl besonders gelegen kommt ist kapitan hofmann
# 10418   in der szene erscheint peters ein bekannter kanadischer komiker indianischer herkunft der kurzlich als moderator bei der sendung my violent torpedo of truth von charlie sheen arbeitete als jesuskind
# 18828                                                                                                         seiner ansicht nach konnten alle mitglieder beider vereine kunftig wieder an einem strang ziehen
# 1899   nach unseren informationen hat kubatov wahrend der ermittlungen gestanden rechnungen im namen der gmbh an die vereine atlasz und hoppa sowie an egyutt a harmadik evezredert alapitvany ausgestellt ...

# %% [markdown]
# Looka good

# %% [markdown]
# **again make test_text file**

# %%
df_test.to_csv(r'test_data.txt', header=None, index=None, sep=' ', mode='a')
df_test.to_pickle('test_data.pkl')
